# %%
from google.cloud import bigquery
from google.cloud.bigquery import LoadJobConfig, SourceFormat
from google.oauth2 import service_account

from glob import glob

import os
import csv
from itertools import islice
from pprint import pprint as print

PATH_CREDENIAL_FILE = "/Users/pc-2312002/work/poc-warehouse-copurs/config/poc-bigquery-408603-c15bdbb69a0e.json"
PATH_FILE = '/Users/pc-2312002/work/poc-warehouse-copurs/poc-on-prem-corpus/dump/2023-12-26/corpus/corpus_part_003.csv'

# BigQuery 클라이언트 설정
credentials = service_account.Credentials.from_service_account_file(PATH_CREDENIAL_FILE)
client = bigquery.Client(credentials=credentials, project=credentials.project_id, location="asia-northeast3")

# 대상 데이터셋과 테이블 지정
dataset_id = 'poc_dataset_002'
table_id = 'corpus'
table_ref = client.dataset(dataset_id).table(table_id)

# %%
# 로드 작업 구성
job_config = LoadJobConfig()
job_config.source_format = SourceFormat.CSV
job_config.skip_leading_rows = 1  # 첫 번째 행이 헤더인 경우
job_config.write_disposition = 'WRITE_APPEND'  # 기존 테이블에 데이터 추가

# %%
from google.cloud import bigquery

table = client.get_table(table_ref)  # API 요청

# 테이블 스키마 출력
print("Table schema: {}".format(table.schema))
# Out:
# ("Table schema: [SchemaField('id', 'INTEGER', 'NULLABLE', None, None, (), "
#  "None), SchemaField('lang_id', 'INTEGER', 'NULLABLE', None, None, (), None), "
#  "SchemaField('text', 'STRING', 'NULLABLE', None, None, (), None)]")

# %%
with open(PATH_FILE, "r") as csv_file:
    csv_reader = csv.reader(csv_file)
    
    for idx, row in enumerate(islice(csv_reader, 1, None)):
        
        if len(row) != 3:
            print("", row)
            continue
        
        rows_to_insert = [
            {
                "id": int(row[0]),
                "lang_id": int(row[1]),
                "text": row[2]
            }
        ]
        print(rows_to_insert)
        
        errors = client.insert_rows(table_ref, rows_to_insert, selected_fields=table.schema)
        if errors:
             print("Errors occurred while inserting rows: {}".format(errors))
# Out:
# [{'id': 838300, 'lang_id': 11, 'text': '这需要延长多一天直至明天。'}]
# [{'id': 838301, 'lang_id': 11, 'text': '大家应该明天之前提交项目。'}]
# [{'id': 838302, 'lang_id': 11, 'text': '给我到明天一个确切的答案'}]
# [{'id': 838303, 'lang_id': 11, 'text': '到明天我两个小时内做事。'}]
# [{'id': 838304, 'lang_id': 11, 'text': '它应该在明天进行安装'}]
# [{'id': 838305, 'lang_id': 11, 'text': '到明天我不会忙的。'}]
# [{'id': 838306, 'lang_id': 11, 'text': '工作到明天然后回韩国的。'}]
# [{'id': 838307, 'lang_id': 11, 'text': '明天也打算去那儿 但是明天也下雨'}]
# [{'id': 838309, 'lang_id': 11, 'text': '明天也在同样的地方下车吗?'}]
# [{'id': 838310, 'lang_id': 11, 'text': '明天也在同一的时间见面吧。'}]
# [{'id': 838308, 'lang_id': 11, 'text': '明天也要申请授课吗?'}]
# [{'id': 838277, 'lang_id': 11, 'text': '她明天谈话后,我会打电话给你。'}]
# [{'id': 838269, 'lang_id': 11, 'text': '还是明天去好了,明天你几点结束呢?'}]
# [{'id': 838266, 'lang_id': 11, 'text': '明天的训练时间是什么时候?'}]
# [{'id': 838264, 'lang_id': 11, 'text': '我必须准备一些资料,明天向老板报告。'}]
# [{'id': 838255, 'lang_id': 11, 'text': '你明天到公司打个电话,我帮你申请预定。'}]
# ...
