# %%
import os
import pandas as pd
import boto3
from botocore.exceptions import NoCredentialsError

import ujson as json
import psycopg2
from botocore.exceptions import ClientError


AWS_REGION="ap-northeast-2"
S3_BUCKET="flitto"

REDSHIFT_CLUSTER="redshift-cluster-1"
IAM_ROLE_ARN="arn:aws:iam::946551077663:role/service-role/AmazonRedshift-CommandsAccessRole-20231219T175533"

DATABASE_NAME="corpus"
DATABASE_USER="awsuser"

# %%
# AWS 자격 증명 로드
try:
    s3 = boto3.client('s3')
    redshift = boto3.client('redshift-data')

except NoCredentialsError:
    print('AWS 자격 증명 파일을 찾을 수 없습니다. ~/.aws/credentials 파일이 올바르게 설정되었는지 확인하세요.')

dtype_to_redshift_data_types ={
    'int64': 'INTEGER',
    'float64': 'FLOAT',
    'object': 'VARCHAR(255)'
}

response = s3.list_objects_v2(Bucket=S3_BUCKET)

# %%
def get_csv_files():
    response = s3.list_objects_v2(Bucket=S3_BUCKET)

    # CSV 파일 목록 출력
    csv_files = [ (os.path.splitext(obj['Key'])[0], f"s3://{S3_BUCKET}/{obj['Key']}") for obj in response.get('Contents', []) if obj['Key'].endswith('.csv')]
    return csv_files

csv_files = get_csv_files()

# %%
def get_secret():
    secret_name = 'redshift!redshift-cluster-1-awsuser'
    region_name = 'ap-northeast-2'
    
    # Create a Secrets Manager client
    session = boto3.session.Session()
    client = session.client(
        service_name='secretsmanager',
        region_name=region_name
    )

    try:
        get_secret_value_response = client.get_secret_value(
            SecretId=secret_name
        )
    except ClientError as e:
        # For a list of exceptions thrown, see
        # https://docs.aws.amazon.com/secretsmanager/latest/apireference/API_GetSecretValue.html
        raise e

    secret = get_secret_value_response['SecretString']
    return secret

secret = json.loads(get_secret())
conn = psycopg2.connect(
    dbname=DATABASE_NAME,
    user=secret['username'],
    password=secret['password'],
    host='redshift-cluster-1.chzlcffktkrj.ap-northeast-2.redshift.amazonaws.com',
    port=5439
)

cursor = conn.cursor()

# %%
def parse_s3_url(url):
    import re
    match = re.match(r's3://([^/]+)/(.+)', s3_url)
    if match:
        return match.groups()
    else:
        raise ValueError(f"Invalid S3 URL: {s3_url}")

table_name, s3_url = get_csv_files()[0]
b_name, obj_key = parse_s3_url(s3_url)

obj = s3.get_object(Bucket=b_name, Key=obj_key)
data = obj['Body'].read()
data
# Out:
# b'id,lang_id1,lang_id2,tag_id,cnt\n1,3,11,1,212370\n2,3,11,2,140894\n3,3,11,7,76085\n11,3,17,1,344402\n24382,3,17,21,105\n24383,3,17,19,25\n24384,3,17,20,17\n21093,3,17,17,3\n24392,3,20,21,47\n24397,3,20,19,16\n24398,3,20,20,12\n33,3,22,6,5031\n24408,3,22,19,9\n24409,3,22,20,4\n24410,3,22,21,27\n37,3,22,5,3189\n2488,3,22,0,225\n24431,3,27,21,54\n24433,3,27,19,12\n24434,3,27,20,6\n55,3,30,4,4855\n24445,3,30,21,54\n24446,3,30,19,18\n24447,3,30,20,6\n21144,3,30,17,3\n62,3,33,8,15215\n24459,3,33,21,75\n24460,3,33,19,28\n24461,3,33,20,15\n21155,3,33,17,3\n69,3,38,1,127814\n24468,3,38,21,43\n24471,3,38,19,11\n24474,3,38,20,5\n24482,3,45,21,1\n24488,3,45,20,1\n24497,3,48,19,14\n24498,3,48,20,7\n24499,3,48,21,18\n89,3,52,7,63852\n24511,3,52,19,18\n24512,3,52,20,10\n24513,3,52,21,29\n24520,3,56,21,41\n24522,3,56,19,11\n24525,3,56,20,8\n24533,3,57,21,1\n24544,3,61,19,12\n24547,3,61,21,38\n24548,3,61,20,7\n24555,3,62,21,1\n23897,3,63,7,2\n24562,3,63,21,2\n12409,3,63,1,1\n24574,11,17,21,273\n24575,11,17,19,28\n24576,11,17,20,29\n12422,11,17,11,4\n126,11,20,9,141810\n127,11,20,7,73406\n124,11,20,1,225091\n129,11,20,8,8437\n24588,11,20,21,66\n24589,11,20,19,11\n24590,11,20,20,19\n24600,11,22,19,7\n24601,11,22,20,17\n24602,11,22,21,89\n146,11,27,6,5519\n24624,11,27,21,109\n24625,11,27,19,8\n24634,11,30,20,44\n172,11,38,2,52873\n24660,11,38,21,41\n24663,11,38,19,4\n1655,11,45,7,204\n1659,11,45,6,874\n24673,11,45,21,1\n184,11,48,7,65436\n24686,11,48,19,13\n24687,11,48,20,18\n24688,11,48,21,76\n193,11,52,7,80203\n194,11,52,6,7057\n195,11,52,8,7994\n24700,11,52,19,16\n24701,11,52,20,8\n24702,11,52,21,57\n24709,11,56,21,39\n206,11,56,4,1191\n24712,11,56,19,4\n205,11,56,6,1864\n208,11,56,5,442\n24722,11,57,21,1\n210,11,61,9,53530\n212,11,61,7,34226\n24731,11,61,19,5\n12561,11,63,1,1\n219,17,20,2,336576\n24637,11,30,21,142\n24638,11,30,19,66\n12473,11,30,11,3\n162,11,33,1,478030\n163,11,33,2,623781\n164,11,33,6,59867\n165,11,33,7,749759\n24648,11,33,20,52\n24651,11,33,21,153\n24652,11,33,19,73\n12484,11,33,11,6\n24734,11,61,21,37\n24735,11,61,20,6\n24743,11,62,21,1\n24748,11,63,21,3\n220,17,20,9,233020\n221,17,20,7,167454\n222,17,20,6,16350\n218,17,20,1,353438\n225,17,20,5,6219\n223,17,20,8,21851\n224,17,20,4,11997\n24760,17,20,21,68\n24761,17,20,20,67\n24762,17,20,19,35\n24772,17,22,19,12\n24773,17,22,20,21\n24774,17,22,21,89\n24795,17,27,21,111\n24797,17,27,19,15\n24798,17,27,20,10\n24809,17,30,21,123\n24810,17,30,19,30\n24811,17,30,20,18\n24824,17,33,21,145\n24825,17,33,19,55\n24826,17,33,20,58\n24834,17,33,22,10632\n24840,17,38,21,44\n24843,17,38,19,12\n24846,17,38,20,5\n24856,17,45,21,1\n24858,17,45,20,2\n24860,17,45,19,1\n24870,17,48,19,17\n24967,20,27,21,31\n227,17,22,2,181570\n24871,17,48,20,24\n24872,17,48,21,76\n24971,20,27,20,6\n24972,20,27,19,5\n24983,20,30,21,37\n24984,20,30,19,13\n24985,20,30,20,13\n24996,20,33,21,55\n24997,20,33,20,24\n24998,20,33,19,19\n25384,27,48,21,7\n25385,27,48,19,4\n25397,27,52,20,3\n25398,27,52,21,16\n25399,27,52,19,7\n25406,27,56,21,39\n25408,27,56,19,11\n25411,27,56,20,6\n25420,27,57,21,1\n25430,27,61,19,12\n25431,27,61,21,37\n25433,27,61,20,6\n25442,27,62,21,1\n25448,27,63,21,3\n25457,30,33,20,40\n25460,30,33,21,98\n25461,30,33,19,77\n25470,30,38,21,17\n25473,30,38,19,4\n25483,30,45,21,1\n25496,30,48,19,17\n25497,30,48,20,12\n25498,30,48,21,63\n25510,30,52,19,16\n25511,30,52,20,6\n25512,30,52,21,25\n25519,30,56,21,19\n25522,30,56,19,4\n25540,30,61,19,5\n25543,30,61,21,15\n25545,30,61,20,3\n25554,30,63,21,4\n25566,33,38,21,35\n25569,33,38,19,12\n25572,33,38,20,4\n25582,33,45,21,1\n25584,33,45,20,2\n599,33,48,7,64687\n25595,33,48,19,18\n25596,33,48,20,17\n25597,33,48,21,24\n25608,33,52,20,13\n25609,33,52,19,23\n25610,33,52,21,52\n25617,33,56,21,34\n25620,33,56,19,12\n25622,33,56,20,9\n25631,33,57,21,1\n25641,33,61,19,13\n25644,33,61,21,30\n25645,33,61,20,13\n25653,33,62,21,1\n25657,33,63,21,2\n25662,33,63,4,1\n25663,33,63,8,1\n25668,38,45,21,1\n25684,38,48,19,3\n25685,38,48,21,2\n25695,38,52,21,12\n25696,38, ...

# %%
import psycopg2

conn = psycopg2.connect(
    dbname=DATABASE_NAME,
    user=DATABASE_USER,
    password='YOUR_PASSWORD',
    host=redshift-'cluster-1.chzlcffktkrj.ap-northeast-2.redshift.amazonaws.com',
    port='5439'
)

# %%
conn.commit()

# %%
cursor = conn.cursor()

for csv_file in csv_files:
    s3_url = f"s3://{S3_BUCKET}/{csv_file}"
    df = pd.read_csv(s3_url, nrows=1000)

    table_name = os.path.splitext(csv_file)[0]
    
    create_table_query = f"CREATE TABLE {table_name} (\n"

    for field_name, data_type in zip(df.columns, df.dtypes):
        
        if data_type == 'object' and table_name == 'corpus':
            create_table_query += f"{field_name} VARCHAR(MAX),\n"
            
        else:
            create_table_query += f"{field_name} {dtype_to_redshift_data_types[str(data_type)]},\n"
    
    create_table_query = create_table_query.rstrip(',\n') + "\n);"
    
    copy_query = f"COPY {table_name} FROM '{s3_url}' IAM_ROLE '{IAM_ROLE_ARN}' FORMAT CSV IGNOREHEADER 1"

    try:    
        cursor.execute(create_table_query)
        print(f"Created {table_name} --")
        
        cursor.execute(copy_query)
        print(f"Updated rows --")
    
    except Exception as error:
        conn.rollback()
        print(error)
        break
# Out:
# Created cnt_2pairs_corpus --
# Updated rows --
# Created cnt_3pairs_corpus --
# Updated rows --
# Created cnt_mono_corpus --
# Updated rows --
# Created corpus --
# Updated rows --
# Created corpus_tags_map --
# Updated rows --
# Created duplicated_corpus --
# Updated rows --
# Created group_tags_map --
# Updated rows --
# Created languages --
# Updated rows --
# Created parallel_corpus --
# Updated rows --
# Created partners --
# Updated rows --
# Created project_corpus_map --
# Updated rows --
# Created projects --
# Updated rows --
# Created tags --
# Updated rows --
# Created user_meta --
# Updated rows --
# Created voice_corpus --
# Updated rows --

# %%
cursor = conn.cursor()

for table, s3_url in get_csv_files():
    cursor.execute(f'drop table {table}')
    
conn.commit()

# %%
cursor = conn.cursor()
query='''
    SELECT
        A.group_id,
        A.corpus_id AS en_id,
        B.corpus_id AS zh_id,
        corpusA.text AS en,
        corpusB.text AS zh,
        project.title AS en_delivery,
        project.title AS zh_delivery,
        COALESCE(tag1.name, '') AS tag_1,
        COALESCE(gtm1.score, 0) AS score_1,
        COALESCE(tag2.name, '') AS tag_2,
        COALESCE(gtm2.score, 0) AS score_2,
        COALESCE(tag3.name, '') AS tag_3,
        COALESCE(gtm3.score, 0) AS score_3
    FROM 
        parallel_corpus A
        JOIN parallel_corpus B ON A.group_id = B.group_id AND A.lang_id = 17 AND B.lang_id = 11
        LEFT JOIN corpus corpusA ON A.corpus_id = corpusA.id
        LEFT JOIN corpus corpusB ON B.corpus_id = corpusB.id
        LEFT JOIN (
            SELECT corpus_id, MAX(project_id) AS max_project_id
            FROM project_corpus_map
            GROUP BY corpus_id
        ) pcm ON A.corpus_id = pcm.corpus_id
        LEFT JOIN projects project ON pcm.max_project_id = project.id
        LEFT JOIN group_tags_map gtm1 ON A.group_id = gtm1.group_id AND gtm1.priority = 1
        LEFT JOIN tags tag1 ON gtm1.tag_id = tag1.id
        LEFT JOIN group_tags_map gtm2 ON A.group_id = gtm2.group_id AND gtm2.priority = 2
        LEFT JOIN tags tag2 ON gtm2.tag_id = tag2.id
        LEFT JOIN group_tags_map gtm3 ON A.group_id = gtm3.group_id AND gtm3.priority = 3
        LEFT JOIN tags tag3 ON gtm3.tag_id = tag3.id
    
    '''

cursor.execute(query)

# %%
cursor.fetchall()
# Out:
# [(893789,
#   13632279,
#   2393789,
#   'By then, There are people who look me as role model.',
#   '到时候会有人想要把我作为榜样的。',
#   '2019_BYTEDANCE_중일',
#   '2019_BYTEDANCE_중일',
#   'society',
#   0.61,
#   'beauty',
#   0.57,
#   '',
#   0.0),
#  (909136,
#   2914272,
#   2455224,
#   'I sent 30 million won for the budget related to this.',
#   '我们关于这些的预算汇款了3千万。',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'financial',
#   0.99,
#   'business',
#   0.95,
#   'economy',
#   0.83),
#  (666243,
#   1820690,
#   1706546,
#   'Especially secret village must be very popular.',
#   '特别是秘密村在孩子们中间很受欢迎。',
#   '2019_BYTEDANCE_중일',
#   '2019_BYTEDANCE_중일',
#   'beauty',
#   0.69,
#   '',
#   0.0,
#   '',
#   0.0),
#  (5735244,
#   34739201,
#   22215786,
#   'If I stay here, I think I can have a dream with a mighty scale.',
#   '如果住在这里的话,好像可以做一个大大的美梦呢。',
#   None,
#   None,
#   'beauty',
#   0.85,
#   'liberal arts',
#   0.56,
#   '',
#   0.0),
#  (202094,
#   8517732,
#   2866926,
#   "It's already been a month since I entered school.",
#   '我进入学校已经一个月了。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'education',
#   0.96,
#   '',
#   0.0,
#   '',
#   0.0),
#  (441415,
#   1255823,
#   2890825,
#   "I sent you two boxes since I couldn't put them in one single box.",
#   '5个不能报一箱子,因此2个箱子发货了。',
#   '2018_삼성SDS_영한',
#   '2018_삼성SDS_영한',
#   'transport',
#   0.97,
#   'customer service',
#   0.96,
#   'commerce',
#   0.94),
#  (527559,
#   1428230,
#   2935771,
#   'There is nothing interesting in her house.',
#   '她家没有什么好玩的东西。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'economy',
#   0.37,
#   '',
#   0.0,
#   '',
#   0.0),
#  (1505098,
#   4775645,
#   2942812,
#   'The pizza was made of ham, cheese, and vegetables.',
#   '这披萨是又火腿肠奶酪素菜做的。',
#   '2019_NIA_영한_대화',
#   '2019_NIA_영한_대화',
#   'beauty',
#   0.63,
#   '',
#   0.0,
#   '',
#   0.0),
#  (527310,
#   1427732,
#   2953133,
#   'There is no minor in our house.',
#   '我们家没有未成年人。',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'business',
#   0.79,
#   'law',
#   0.68,
#   'legal',
#   0.63),
#  (639032,
#   1651924,
#   1803540,
#   'Can I order a double helping?',
#   '可以点除去脂肪的吗?',
#   '2014_ETRI_중영일한',
#   '2014_ETRI_중영일한',
#   'customer service',
#   0.93,
#   'beauty',
#   0.88,
#   'conversation',
#   0.81),
#  (532317,
#   1437749,
#   2969393,
#   'This company has a lot of potential.',
#   '这公司有潜力。',
#   '2019_NIA_영한_대화',
#   '2019_NIA_영한_대화',
#   'business',
#   0.99,
#   'technology',
#   0.74,
#   'commerce',
#   0.64),
#  (941689,
#   2583520,
#   2977971,
#   'I came here to work.',
#   '我来这儿工作。',
#   '2018_NTT_중영일한',
#   '2018_NTT_중영일한',
#   'business',
#   0.99,
#   'commerce',
#   0.93,
#   'economy',
#   0.8),
#  (243454,
#   2588035,
#   2980190,
#   "I couldn't find perfect fit for me.",
#   '我没找到适合我的衣服。',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'shopping',
#   0.72,
#   'financial',
#   0.56,
#   'transport',
#   0.56),
#  (339381,
#   2640513,
#   3009396,
#   'This is the center of Seoul from the Joseon Dynasty era.',
#   '这里是从朝鲜开始的首尔的重点。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'beauty',
#   0.79,
#   '',
#   0.0,
#   '',
#   0.0),
#  (640342,
#   1654552,
#   1838299,
#   'It will be difficult to stay in Korea without my credit card.',
#   '但是因为丢失了信用卡所以在韩国居住的时间里生活应该会很不方便。',
#   '2014_ETRI_중영일한',
#   '2014_ETRI_중영일한',
#   'financial',
#   0.99,
#   'travel',
#   0.98,
#   'commerce',
#   0.9),
#  (297960,
#   2647844,
#   3013562,
#   'In the zoo inside the department store.',
#   '在商场里面的动物园。',
#   '2018_NTT_중영일한',
#   '2018_NTT_중영일한',
#   'commerce',
#   0.35,
#   '',
#   0.0,
#   '',
#   0.0),
#  (306031,
#   2657588,
#   3019019,
#   'Sophie rides the bus.',
#   '苏菲坐公交通行。',
#   '2018_NTT_중영일한',
#   '2018_NTT_중영일한',
#   'transport',
#   0.99,
#   'travel',
#   0.99,
#   'economy',
#   0.62),
#  (124464,
#   2685863,
#   3034981,
#   'I think that you are my academic adviser.',
#   '你给我的感觉像我的指导老师。',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'education',
#   0.95,
#   'liberal arts',
#   0.71,
#   '',
#   0.0),
#  (637252,
#   1648351,
#   1852398,
#   "Floral rush is small, cute and elegant, so it's mostly used to store jewelry and as a decoration.",
#   '因为小巧并有高端感的花三合主要用来装贵金属或者作为装饰品使用。',
#   '2014_ETRI_중영일한',
#   '2014_ETRI_중영일한',
#   'beauty',
#   0.99,
#   '',
#   0.0,
#   '',
#   0.0),
#  (965162,
#   2747509,
#   3069841,
#   'People find it hard to sleep when the weather is humid.',
#   '天气湿的话人们不容易睡觉。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'society',
#   0.51,
#   '',
#   0.0,
#   '',
#   0.0),
#  (415983,
#   1204921,
#   3071612,
#   'I can not give you more time.',
#   '不能再给你时间了。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'business',
#   0.98,
#   'customer service',
#   0.97,
#   'law',
#   0.92),
#  (8375788,
#   2771061,
#   3083304,
#   'This summer vacation is my last summer vacation as a middle school student.',
#   '这个暑假是作为中学生的最后一个暑假。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'education',
#   0.8,
#   'travel',
#   0.58,
#   '',
#   0.0),
#  (122205,
#   2773699,
#   3084834,
#   'I wish your business flourishes.',
#   '我祝你的事业繁荣昌盛。',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'business',
#   0.98,
#   'commerce',
#   0.86,
#   'economy',
#   0.53),
#  (125354,
#   2789131,
#   3093492,
#   'We live in the opposite side.',
#   '跟你住的地方正好相反。',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'society',
#   0.9,
#   'travel',
#   0.85,
#   'economy',
#   0.63),
#  (230674,
#   2797250,
#   3098122,
#   'He kicked me simultaneously.',
#   '他同时用脚踢我了。',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'sports',
#   0.78,
#   'transport',
#   0.67,
#   'business',
#   0.6),
#  (5906721,
#   34755525,
#   22409678,
#   'Since then, it is said that a ritual in honor of Grandma Pone has been held every year.',
#   '听说从那以后每天都会进行供奉桑妈妈的祭祀活动。',
#   None,
#   None,
#   'society',
#   0.71,
#   'beauty',
#   0.58,
#   '',
#   0.0),
#  (72077,
#   2783989,
#   817896,
#   'I want to see just your eyes.',
#   '我想看你的眼睛。',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'beauty',
#   0.41,
#   '',
#   0.0,
#   '',
#   0.0),
#  (5641567,
#   33186594,
#   22441588,
#   'In the newly opened store at Ebisu, they maintain the things of the head store in Shibuya which are a great value for money, and sophisticated grilled skewers which matches Ebisu street is the main theme.',
#   '在惠比寿的新店铺中,性价比的好处是维持以前涩谷总店的商品,适合惠比寿街道的时尚烤串成为主题。',
#   None,
#   None,
#   'business',
#   0.89,
#   'commerce',
#   0.86,
#   'economy',
#   0.77),
#  (108716,
#   2664103,
#   854535,
#   'Because performance should be acted in next month.',
#   '因为下个月我得表演。',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'business',
#   0.96,
#   'law',
#   0.64,
#   '',
#   0.0),
#  (125458,
#   4925360,
#   871277,
#   'Where do you think the hottest spot is?',
#   '你所想的性感的身体部位。',
#   '2018_NTT_중영일한',
#   '2018_NTT_중영일한',
#   'travel',
#   0.4,
#   '',
#   0.0,
#   '',
#   0.0),
#  (5936388,
#   34758388,
#   22551613,
#   'Looking the azure color and the colors of the flowers on the lake surface would make you unconciously to take a picture.',
#   '映照在湖面的绿色植物和鲜花,让人不由自主就想拍照吧。',
#   None,
#   None,
#   'beauty',
#   0.99,
#   'art',
#   0.64,
#   '',
#   0.0),
#  (191902,
#   2549810,
#   937721,
#   "Canada's weather is similar to that of Korea.",
#   '加拿大的天气跟韩国的相似。',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'beauty',
#   0.14,
#   '',
#   0.0,
#   '',
#   0.0),
#  (218513,
#   2430350,
#   964332,
#   'The most careful point is.',
#   '最劳神的地方是。',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'business',
#   0.49,
#   '',
#   0.0,
#   '',
#   0.0),
#  (231975,
#   2431817,
#   977794,
#   'They did not do it for sure when they said so.',
#   '那时候他们说不做就真的不做了。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'conversation',
#   0.88,
#   'business',
#   0.77,
#   'customer service',
#   0.76),
#  (569009,
#   1511241,
#   21199032,
#   "I wanted to see you but it was so regrettable that we couldn't.",
#   '本想见你没见着很失落。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'travel',
#   0.92,
#   'customer service',
#   0.84,
#   '',
#   0.0),
#  (1544192,
#   4893611,
#   21201295,
#   'Is your dream to become a lawyer?',
#   '你的梦想是当律师吗?',
#   '2018_NTT_중영일한',
#   '2018_NTT_중영일한',
#   'law',
#   0.7,
#   '',
#   0.0,
#   '',
#   0.0),
#  (390585,
#   1154087,
#   21201752,
#   'Do you want me to pray for your own business?',
#   '你想让我为了你的工作做祷告吗?',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'business',
#   0.95,
#   'commerce',
#   0.54,
#   'economy',
#   0.53),
#  (119001,
#   2722445,
#   21207970,
#   'You have to leave on Monday, what should we do?',
#   '我星期一要走了,怎么办?',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'travel',
#   0.99,
#   'conversation',
#   0.95,
#   'business',
#   0.94),
#  (1044857,
#   3464553,
#   3472579,
#   'You can get there by bus in less than 30 minutes.',
#   '乘公交的话30分钟之内就可以到了。',
#   '2016_ETRI_아중영프독일한러스',
#   '2016_ETRI_아중영프독일한러스',
#   'transport',
#   0.99,
#   'travel',
#   0.98,
#   'technology',
#   0.95),
#  (656468,
#   20980257,
#   1686926,
#   'In the beginning, in order to protect their fist, they wrapped their hands with soft calf skins in form of a bandage.',
#   '最初为了保护拳头,把光滑的小牛犊的皮剪成绷带的模样缠在手上。',
#   '2019_BYTEDANCE_중일',
#   '2019_BYTEDANCE_중일',
#   'economy',
#   0.39,
#   '',
#   0.0,
#   '',
#   0.0),
#  (657418,
#   1845819,
#   1688832,
#   'Korean people tend to eat sea mustard soup on their birthday and after giving birth.',
#   '韩国人是生日的时候,出生之后也是,都是要喝海带汤的。',
#   '2019_BYTEDANCE_중일',
#   '2019_BYTEDANCE_중일',
#   'society',
#   0.75,
#   '',
#   0.0,
#   '',
#   0.0),
#  (657563,
#   1811111,
#   1689122,
#   'I think Sheeodo is a quiet island.',
#   '细于岛好像真是个很安静的小岛。',
#   '2017_삼성종합기술원_중한',
#   '2017_삼성종합기술원_중한',
#   'beauty',
#   0.85,
#   '',
#   0.0,
#   '',
#   0.0),
#  (5873638,
#   34752405,
#   22216097,
#   'Oahu Island is also popular and will surely heal with its beautiful sea, sunset, and excellent Hawaiian cuisine.',
#   '果然瓦胡岛很有人气,毫无疑问会被美丽的大海、日落、绝品夏威夷料理所治愈。',
#   None,
#   None,
#   'travel',
#   0.97,
#   'medicine',
#   0.97,
#   'beauty',
#   0.97),
#  (982720,
#   1181912,
#   2851819,
#   'How do I use Wi-Fi?',
#   '怎么使用无线网呢?',
#   '2019_NIA_영한_대화',
#   '2019_NIA_영한_대화',
#   'information technology',
#   0.99,
#   'technology',
#   0.99,
#   '',
#   0.0),
#  (193212,
#   8836651,
#   2865291,
#   'I had a horse since the moment I was born.',
#   '出生的时候已经拥有马。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'transport',
#   0.94,
#   'beauty',
#   0.66,
#   'sports',
#   0.54),
#  (803468,
#   2097900,
#   34172230,
#   "You wouldn't talk like that if you really loved me.",
#   '如果你真的爱我,你就不会那样子说话。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'conversation',
#   0.71,
#   '',
#   0.0,
#   '',
#   0.0),
#  (5752327,
#   34740801,
#   22333896,
#   'You can enjoy it over and over because there are lots of special exhibitions or events.',
#   '有很多展览和活动,可以尽情地享受。',
#   None,
#   None,
#   'legal',
#   0.7,
#   'beauty',
#   0.68,
#   'liberal arts',
#   0.63),
#  (918226,
#   2490809,
#   2931853,
#   'Korean song I love you. To you who I love most in the world.',
#   '韩国歌儿爱您世界中我最爱的您。',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'beauty',
#   0.65,
#   '',
#   0.0,
#   '',
#   0.0),
#  (625745,
#   1625123,
#   1803226,
#   'What is Inha university famous for?',
#   '仁荷大学以什么为有名呢?',
#   '2017_ETRI_아중영일한',
#   '2017_ETRI_아중영일한',
#   'education',
#   0.54,
#   '',
#   0.0,
#   '',
#   0.0),
#  (532985,
#   1439085,
#   2973971,
#   'This is feeding machine.',
#   '这是喂食器。',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'technology',
#   0.95,
#   'financial',
#   0.77,
#   'engineering',
#   0.55),
#  (657894,
#   1689784,
#   1818633,
#   "Doesn't it no matter if you jump forward or backward?",
#   '之前跳还是之后跳都没啥差别吧。',
#   '2020_MICROSOFT_14개언어',
#   '2020_MICROSOFT_14개언어',
#   'travel',
#   0.96,
#   'transport',
#   0.91,
#   'legal',
#   0.88),
#  (231315,
#   2612081,
#   2993272,
#   "He doesn't answer the phone. I will go to work.",
#   '他不接电话,我要去工作了。',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'business',
#   0.91,
#   'customer service',
#   0.59,
#   '',
#   0.0),
#  (650778,
#   1675488,
#   1844251,
#   'There is a kid zone for the family visitors in Munhak Stadium.',
#   '仁川文化竞技场里有以家庭为单位的观众为对象运营的儿童区。',
#   '2014_ETRI_중영일한',
#   '2014_ETRI_중영일한',
#   'beauty',
#   0.67,
#   '',
#   0.0,
#   '',
#   0.0),
#  (232224,
#   2718430,
#   3053509,
#   'They took pictures avoiding the building.',
#   '他们避开大楼照相了。',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'social media',
#   0.92,
#   '',
#   0.0,
#   '',
#   0.0),
#  (329377,
#   8867770,
#   3066461,
#   'Thank you for cheering on my sister.',
#   '谢谢去给我姐姐加油。',
#   '2019_NIA_영한_대화',
#   '2019_NIA_영한_대화',
#   'beauty',
#   0.85,
#   'social media',
#   0.74,
#   'customer service',
#   0.7),
#  (35157,
#   2356836,
#   780976,
#   'Choosing something is easy for me.',
#   '这是很容易选择一些适合我。',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'shopping',
#   0.57,
#   '',
#   0.0,
#   '',
#   0.0),
#  (973278,
#   2808109,
#   3104264,
#   'I go to school with Jessica.',
#   '我和杰西卡去上学。',
#   '2018_NTT_중영일한',
#   '2018_NTT_중영일한',
#   'education',
#   0.91,
#   'liberal arts',
#   0.67,
#   'conversation',
#   0.52),
#  (392557,
#   1158034,
#   816979,
#   'Dress which is not quite for age.',
#   '不适合年龄的衣服。',
#   '2014_NAVER_영인',
#   '2014_NAVER_영인',
#   'fashion',
#   0.95,
#   'beauty',
#   0.71,
#   '',
#   0.0),
#  (78138,
#   2820033,
#   823957,
#   'Why do you ignore my words?',
#   '你为什么忽视我的话。',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'conversation',
#   0.91,
#   'customer service',
#   0.58,
#   '',
#   0.0),
#  (5634555,
#   33187297,
#   22475376,
#   'The bus was also listed in the guidebook, but the bus terminal was difficult to recognize so I asked when I bought the map at the kiosk in front of the station.',
#   '虽然旅游手册上也有公交车信息,但因为公交汽车总站很难懂,所以在车站前的售货亭买地图的时候问了一下。',
#   None,
#   None,
#   'transport',
#   0.99,
#   'travel',
#   0.98,
#   'commerce',
#   0.69),
#  (127190,
#   2764914,
#   873009,
#   'How do you feel about the Korea?',
#   '你对韩国有什么感觉?',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'conversation',
#   0.8,
#   'travel',
#   0.66,
#   'society',
#   0.59),
#  (476033,
#   1325136,
#   922128,
#   "It doesn't show on the web page.",
#   '它不会显示在网页上。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'technology',
#   0.68,
#   'travel',
#   0.59,
#   'financial',
#   0.58),
#  (177463,
#   2390450,
#   923282,
#   'Yeah, I arrived korea one month ago.',
#   '是的,一个月前到达韩国了。',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'travel',
#   0.99,
#   'conversation',
#   0.82,
#   'transport',
#   0.75),
#  (200432,
#   2544697,
#   946251,
#   'But i will make it really short.',
#   '但是我会把它变的很短。',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'business',
#   0.64,
#   'travel',
#   0.62,
#   'financial',
#   0.6),
#  (287533,
#   2699935,
#   1033351,
#   'I started working after I got the second visa.',
#   '得第二个签证后工作了。',
#   '2019_NIA_영한_대화',
#   '2019_NIA_영한_대화',
#   'business',
#   0.89,
#   'economy',
#   0.72,
#   'legal',
#   0.7),
#  (297144,
#   2717181,
#   1042962,
#   'There are many stars in the night.',
#   '晚上,可以看见许多星星。',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'beauty',
#   0.81,
#   '',
#   0.0,
#   '',
#   0.0),
#  (330453,
#   2628880,
#   1076271,
#   'According to the picture that you sent us, there are some parts which do not generate the interference.',
#   '看我们收到的照片,有没有干涉的部分。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'technology',
#   0.67,
#   'computer',
#   0.65,
#   'engineering',
#   0.64),
#  (334794,
#   27043125,
#   1080612,
#   'Can I make a certificate for a youth hostel now?',
#   '青年旅舍是现在可以做吗?',
#   '2019_NIA_영한_대화',
#   '2019_NIA_영한_대화',
#   'business',
#   0.87,
#   'legal',
#   0.72,
#   'conversation',
#   0.53),
#  (908386,
#   2912876,
#   2452312,
#   'Where do the students skate during the skating class?',
#   '学生们在哪儿上在学校做的滑冰课?',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'sports',
#   0.97,
#   '',
#   0.0,
#   '',
#   0.0),
#  (650088,
#   1844246,
#   1674105,
#   "The way of drawing lots is strange. If then, isn't there any game korean team play until the preliminary games will be finished?",
#   '分组抽签的方式很特别啊。那么韩国在预选赛结束之前不需要出赛了。',
#   '2019_BYTEDANCE_중일',
#   '2019_BYTEDANCE_중일',
#   'sports',
#   0.62,
#   '',
#   0.0,
#   '',
#   0.0),
#  (981911,
#   8902868,
#   2849427,
#   'Because I can earn money with fame.',
#   '因为有极高的声誉,可以赚钱。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'financial',
#   0.93,
#   'legal',
#   0.69,
#   '',
#   0.0),
#  (552056,
#   1477267,
#   2910602,
#   'Where is our soul comes from.',
#   '我们的灵魂是从哪里来的?',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'liberal arts',
#   0.08,
#   '',
#   0.0,
#   '',
#   0.0),
#  (908630,
#   2453223,
#   2913304,
#   'I rode the bus to buy some bread yesterday.',
#   '我昨天为了买面包坐公交车。',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'transport',
#   0.99,
#   'travel',
#   0.99,
#   'commerce',
#   0.96),
#  (912443,
#   2468178,
#   2920726,
#   'Change 49 won back to him.',
#   '给他找49元吧。',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'business',
#   0.86,
#   'financial',
#   0.82,
#   'customer service',
#   0.66),
#  (5906128,
#   34755465,
#   22498029,
#   'Odawara is famous for seafood and this place is where you can have everything. Great place!',
#   '小田原的海鲜很有名,我认为这是一个能品尝到那所有滋味,充满了魅力的地方!',
#   None,
#   None,
#   'beauty',
#   0.62,
#   '',
#   0.0,
#   '',
#   0.0),
#  (414113,
#   1201181,
#   2934627,
#   "I ate shabu-shabu with my mom's friends.",
#   '与妈妈和朋友们一起吃了呷哺呷哺。',
#   '2019_EPOPSOFT_영한',
#   '2019_EPOPSOFT_영한',
#   'beauty',
#   0.4,
#   '',
#   0.0,
#   '',
#   0.0),
#  (226193,
#   2511120,
#   2942047,
#   'After that day, she left looking for her new life as his advice.',
#   '之后她按他的参谋为了找新的生活离开了。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'travel',
#   0.97,
#   '',
#   0.0,
#   '',
#   0.0),
#  (923976,
#   2513628,
#   2943311,
#   'This ride is for only those who are below 14.',
#   '这个娱乐设施是给十四岁以下的人。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'transport',
#   0.99,
#   'travel',
#   0.98,
#   'technology',
#   0.58),
#  (5752576,
#   34740830,
#   22537661,
#   "It's blue cheese with a pretty strong scent, but if you make it into tartar, it has a good balance with raw meat.",
#   '有很强香气的羊乳蓝芝士,做成塔塔酱,跟生肉很搭。',
#   None,
#   None,
#   'beauty',
#   0.77,
#   '',
#   0.0,
#   '',
#   0.0),
#  (5778012,
#   34743316,
#   22572950,
#   'It became popular because it was a restaurant where you can eat hamburgers as plentiful as America which is birthplace.',
#   '作为能吃到正宗美国那样的汉堡包的店很受欢迎。',
#   None,
#   None,
#   'marketing',
#   0.96,
#   '',
#   0.0,
#   '',
#   0.0),
#  (5876518,
#   34752681,
#   22587198,
#   'I introduced a store where you can luxuriate in the selected special sweets which also have good prices for your wallet.',
#   '介绍了一家既实惠又有特色的甜品店。',
#   None,
#   None,
#   'marketing',
#   0.86,
#   'commerce',
#   0.83,
#   'economy',
#   0.65),
#  (1506726,
#   4780616,
#   2966990,
#   'They were punished to eat cookies until they die.',
#   '他们的处分就是吃饼干至死。',
#   '2018_NTT_중영일한',
#   '2018_NTT_중영일한',
#   'law',
#   0.93,
#   'society',
#   0.84,
#   'business',
#   0.6),
#  (945037,
#   2596827,
#   2984561,
#   'I will guide you.',
#   '我会引导你。',
#   '2018_NTT_중영일한',
#   '2018_NTT_중영일한',
#   'customer service',
#   0.83,
#   'travel',
#   0.78,
#   'education',
#   0.69),
#  (639526,
#   1652920,
#   1805215,
#   'What is inside this?',
#   '这个是什么馅的?',
#   '2017_ETRI_아중영일한',
#   '2017_ETRI_아중영일한',
#   'financial',
#   0.12,
#   '',
#   0.0,
#   '',
#   0.0),
#  (364905,
#   2610079,
#   2992177,
#   'But my girfriend was afraid.',
#   '但是我的女朋友很害怕。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'transport',
#   0.59,
#   'conversation',
#   0.52,
#   '',
#   0.0),
#  (947068,
#   2612705,
#   2993668,
#   'People been there before me.',
#   '已有人比我先到。',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'travel',
#   0.7,
#   'society',
#   0.69,
#   'conversation',
#   0.53),
#  (299420,
#   4962636,
#   2997267,
#   'I want to live without help from my parents.',
#   '想没有父母的帮助而生活。',
#   '2018_NTT_중영일한',
#   '2018_NTT_중영일한',
#   'financial',
#   0.63,
#   '',
#   0.0,
#   '',
#   0.0),
#  (1528778,
#   26915345,
#   3041444,
#   'Can I take a photo with you inside?',
#   '我能和你拍个照吗?',
#   '2019_NIA_영한_대화',
#   '2019_NIA_영한_대화',
#   'social media',
#   0.87,
#   'technology',
#   0.86,
#   'beauty',
#   0.73),
#  (278302,
#   2752555,
#   3072751,
#   'I made food for my daughter.',
#   '为了月亮做了食物。',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'beauty',
#   0.42,
#   '',
#   0.0,
#   '',
#   0.0),
#  (941320,
#   2582021,
#   749164,
#   'It is amazing when I see teenager fan.',
#   '我看十代粉丝很神奇。',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'beauty',
#   0.94,
#   'sports',
#   0.62,
#   '',
#   0.0),
#  (295776,
#   2776302,
#   3086334,
#   'I went to the station to accomplish the mission.',
#   '为了完成任务去了车站。',
#   '2019_NIA_영한_대화',
#   '2019_NIA_영한_대화',
#   'travel',
#   0.99,
#   'transport',
#   0.92,
#   'science',
#   0.88),
#  (1556364,
#   4940359,
#   766663,
#   'It would be the same in any other country.',
#   '关于那件事不管哪个国家都会一样的。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   '',
#   0.0,
#   '',
#   0.0,
#   '',
#   0.0),
#  (271800,
#   2805267,
#   3102648,
#   'The document which your CEO sent is just for him.',
#   '你的老板发的文件是为那个人的文件。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'business',
#   0.99,
#   'beauty',
#   0.72,
#   'commerce',
#   0.69),
#  (56731,
#   8875207,
#   802550,
#   'I need to work from now on.',
#   '我现在要工作。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'business',
#   0.96,
#   'economy',
#   0.73,
#   'financial',
#   0.67),
#  (72009,
#   8910775,
#   817828,
#   "I don't mind about the part.",
#   '我对那部分一点都不在乎。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'legal',
#   0.68,
#   'business',
#   0.55,
#   'engineering',
#   0.5),
#  (135865,
#   4899892,
#   881684,
#   'A lot of couples go on a date there.',
#   '很多恋人们去那里约会。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'beauty',
#   0.82,
#   '',
#   0.0,
#   '',
#   0.0),
#  (213840,
#   2638417,
#   959659,
#   'I have a pic that took in the hotel.',
#   '有在酒店一起照的照片。',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'travel',
#   0.91,
#   'beauty',
#   0.68,
#   '',
#   0.0),
#  (336714,
#   2674867,
#   1082532,
#   'This picture seems to picture of quayside during the holiday season.',
#   '这张照片好像是假期码头的照片。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'beauty',
#   0.78,
#   'travel',
#   0.66,
#   'art',
#   0.52),
#  (6839675,
#   25091984,
#   25091983,
#   'The central plains, with its core, has always been in the forefront of the development of civilization.',
#   '为核心的中原在文明发展历程中始终走在前列。',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'society',
#   0.79,
#   'beauty',
#   0.75,
#   '',
#   0.0),
#  (6876365,
#   25165376,
#   25165375,
#   'Casa Island is an excellent diving paradise with a rich variety of corals and fish.',
#   '卡萨岛是顶级的潜水天堂,珊瑚和鱼都很丰富。',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'beauty',
#   0.95,
#   '',
#   0.0,
#   '',
#   0.0),
#  (6820002,
#   25052624,
#   25052623,
#   'Lady, tonight I care about nobody but you.',
#   '姐姐,今夜我不关心别人,我只想你。',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'customer service',
#   0.89,
#   'conversation',
#   0.75,
#   'marketing',
#   0.56),
#  (6824217,
#   25061056,
#   25061055,
#   'I originally wanted to take a few pictures of the hotel breakfast, but the hotel restaurant manager was not allowed to take pictures, so I gave up.',
#   '本来想拍几张酒店早餐的,起料酒店餐厅管理人员不允许拍摄,那就算了吧。',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'travel',
#   0.54,
#   '',
#   0.0,
#   '',
#   0.0),
#  (4524033,
#   18315540,
#   5524546,
#   'He was fatter than now.',
#   '他比现在更胖。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'transport',
#   0.52,
#   '',
#   0.0,
#   '',
#   0.0),
#  (989343,
#   1446470,
#   5548577,
#   'Today is just Friday.',
#   '今天只是星期五。',
#   '2018_NTT_중영일한',
#   '2018_NTT_중영일한',
#   'economy',
#   0.5,
#   '',
#   0.0,
#   '',
#   0.0),
#  (992257,
#   1218933,
#   5559889,
#   'I drank alone after a long time.',
#   '难得一个人喝酒。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'economy',
#   0.38,
#   '',
#   0.0,
#   '',
#   0.0),
#  (2522760,
#   8384016,
#   7912496,
#   'If I get a chance, I would like to visit again next year.',
#   '如果有机会明年也想去。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'travel',
#   0.97,
#   'beauty',
#   0.87,
#   '',
#   0.0),
#  (2523600,
#   8439794,
#   7914200,
#   'I am having a good time here studying English.',
#   '我在这里学着英语,过得很好。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'education',
#   0.86,
#   'literature',
#   0.68,
#   'liberal arts',
#   0.54),
#  (2532653,
#   8484751,
#   7932443,
#   'Can you contact me via Kakaotalk?',
#   '你能和我用kakao talk联系吗?',
#   '2018_APPLE_아중영일한러',
#   '2018_APPLE_아중영일한러',
#   'social media',
#   0.99,
#   'technology',
#   0.98,
#   'information technology',
#   0.96),
#  (6531985,
#   23666279,
#   24540672,
#   'And this is a bit funny and sad at the same time.',
#   '而且这个有点搞笑。',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'art',
#   0.49,
#   '',
#   0.0,
#   '',
#   0.0),
#  (2537249,
#   8494053,
#   7941683,
#   'You can have it before I come.',
#   '我走之前你先吃着吧。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'legal',
#   0.86,
#   'travel',
#   0.82,
#   'business',
#   0.78),
#  (1642826,
#   9094332,
#   5603197,
#   'Yes, a cup of lemonade please. Please remove the ice.',
#   '是的,请给我一杯柠檬汽水,不要放冰。',
#   '2020_MICROSOFT_14개언어',
#   '2020_MICROSOFT_14개언어',
#   'customer service',
#   0.99,
#   'conversation',
#   0.95,
#   'beauty',
#   0.9),
#  (7186906,
#   25786688,
#   25786687,
#   'But its charms are much more than that. Because it is not only an exhibition hall but also a place to experience.',
#   '但它的魅力远不止如此,因为这儿不仅是一座展示馆,更是一个体验场。',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'beauty',
#   0.89,
#   'travel',
#   0.66,
#   'liberal arts',
#   0.54),
#  (6089626,
#   22760588,
#   24303975,
#   'Ghiberti who carved his face on the golden gate.',
#   '把自己的脸放在金色门上的吉贝尔蒂。',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'art',
#   0.99,
#   'beauty',
#   0.92,
#   'business',
#   0.5),
#  (980169,
#   1460423,
#   5611583,
#   'We should forget you.',
#   '我们得忘掉你。',
#   '2018_NTT_중영일한',
#   '2018_NTT_중영일한',
#   'business',
#   0.94,
#   'economy',
#   0.5,
#   '',
#   0.0),
#  (554320,
#   1481801,
#   5635813,
#   "Why doesn't he answer?",
#   '为什么他不回答?',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'customer service',
#   0.42,
#   '',
#   0.0,
#   '',
#   0.0),
#  (2509099,
#   9077076,
#   7884729,
#   'Is there a bus route to that place?',
#   '有到那里的公交线路吗?',
#   '2018_APPLE_영일한',
#   '2018_APPLE_영일한',
#   'transport',
#   0.98,
#   'travel',
#   0.96,
#   'conversation',
#   0.57),
#  (2510585,
#   8388628,
#   7887740,
#   'You have to make a deposit of 30% of the contract fee.',
#   '你需要将签约金的30%汇过来。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'financial',
#   0.99,
#   'business',
#   0.97,
#   'commerce',
#   0.77),
#  (2546894,
#   9095648,
#   7961485,
#   'Yes, you just need to show us the room card.',
#   '是的,只给我们看客房门卡就可以。',
#   '2018_APPLE_영일한',
#   '2018_APPLE_영일한',
#   'legal',
#   0.95,
#   'business',
#   0.95,
#   'financial',
#   0.94),
#  (6183366,
#   22949212,
#   24323342,
#   'It was the very scene of showing the life of the two persons when they kept apologizing on the bus aboard.',
#   '一上公车就不停地道歉,是让人很容易了解到两个人一生的场面。',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'transport',
#   0.99,
#   'travel',
#   0.98,
#   'beauty',
#   0.74),
#  (388822,
#   1150560,
#   5519852,
#   'Do we have to have a class in this time?',
#   '得一直在这个时间上课吗?',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'education',
#   0.85,
#   'liberal arts',
#   0.56,
#   '',
#   0.0),
#  (507414,
#   1387919,
#   5658444,
#   'She took the money from me and played Casino.',
#   '她从我这里拿钱,去赌场玩游戏了。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'financial',
#   0.98,
#   'business',
#   0.69,
#   'commerce',
#   0.51),
#  (1514611,
#   4806113,
#   5535733,
#   "The turtle's body is divided in three parts.",
#   '乌龟的身体由三个构成。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'beauty',
#   0.82,
#   'art',
#   0.77,
#   'transport',
#   0.7),
#  (405698,
#   1184336,
#   5675130,
#   'How many trees are there in the house?',
#   '他家有多少棵树?',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'science',
#   0.16,
#   '',
#   0.0,
#   '',
#   0.0),
#  (2553577,
#   9099511,
#   7975150,
#   'Are you going to marry a Korean too?',
#   '你也要和韩国人结婚吗?',
#   '2018_APPLE_영일한',
#   '2018_APPLE_영일한',
#   'conversation',
#   0.87,
#   'society',
#   0.66,
#   '',
#   0.0),
#  (2554949,
#   8467287,
#   7977913,
#   'Is your daughter sitting on the table?',
#   '你女儿坐在桌子上吗?',
#   '2018_APPLE_아중영일한러',
#   '2018_APPLE_아중영일한러',
#   'education',
#   0.37,
#   '',
#   0.0,
#   '',
#   0.0),
#  (503247,
#   1379583,
#   5680421,
#   'Put radish in the water and boil it.',
#   '把萝卜放入水中,煮沸。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'beauty',
#   0.69,
#   'economy',
#   0.54,
#   '',
#   0.0),
#  (2555703,
#   9100765,
#   7979426,
#   'Call me if you miss me.',
#   '你想我就打电话吧。',
#   '2017_ETRI_아중영일한',
#   '2017_ETRI_아중영일한',
#   'customer service',
#   0.95,
#   'conversation',
#   0.88,
#   'travel',
#   0.79),
#  (6537368,
#   34762659,
#   24340414,
#   "It's like a fragile pair of flat shoes suffers such a big disaster?",
#   '一双娇嫩的单鞋就这样被大惨了,不是吗?',
#   None,
#   None,
#   'fashion',
#   0.02,
#   '',
#   0.0,
#   '',
#   0.0),
#  (2522027,
#   8560175,
#   7911012,
#   'Muscles help to move.',
#   '肌肉帮身体动起来。',
#   '2017_ETRI_아중영일한',
#   '2017_ETRI_아중영일한',
#   'transport',
#   0.9,
#   'travel',
#   0.78,
#   '',
#   0.0),
#  (2558844,
#   8376158,
#   7985750,
#   'Every day we designate the person in charge of the office administration.',
#   '每天指定办公室业务负责人。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'business',
#   0.91,
#   '',
#   0.0,
#   '',
#   0.0),
#  (2560440,
#   9106682,
#   7988970,
#   'Taxes are different for each state in the U.S.',
#   '美国各州税不同。',
#   '2018_APPLE_영일한',
#   '2018_APPLE_영일한',
#   'financial',
#   0.92,
#   'economy',
#   0.62,
#   '',
#   0.0),
#  (960285,
#   13957519,
#   5697446,
#   "I thought that i was going to Philippines but now I can't go.",
#   '我还以为我能再去菲律宾,但是没去成。',
#   '2018_삼성SDS_영한',
#   '2018_삼성SDS_영한',
#   'travel',
#   0.98,
#   'transport',
#   0.5,
#   '',
#   0.0),
#  (2530511,
#   8456007,
#   7928127,
#   'I got him to put earmuffs on immediately.',
#   '我立即让把耳套带上。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'customer service',
#   0.94,
#   'education',
#   0.91,
#   'technology',
#   0.9),
#  (6167764,
#   22917819,
#   24355488,
#   'Because I wanted to see sunset, freedom of the nightfall and the comfort feeling that the lake gives together.',
#   '因为我想在黄昏晚霞时,观赏湖水带来的舒适感和自由。',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'beauty',
#   0.93,
#   'travel',
#   0.87,
#   '',
#   0.0),
#  (6213051,
#   23008924,
#   24359083,
#   'A lapacho tree, which is said to bloom purple flowers that scatter, was prepared.',
#   '准备了一棵叫做拉法切克的紫花开得花开得格外茂盛的树。',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'beauty',
#   0.94,
#   '',
#   0.0,
#   '',
#   0.0),
#  (1521140,
#   4825027,
#   5579899,
#   'And I think cheese is very developed.',
#   '并且奶酪发展了很多。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'beauty',
#   0.76,
#   '',
#   0.0,
#   '',
#   0.0),
#  (5920504,
#   34756871,
#   22600925,
#   'In front of the city hall, there is a stair gap, and there are different kinds of fountains according to the gap.',
#   '政府大楼前面有台阶,根据台阶不同有不一样的喷泉。',
#   None,
#   None,
#   'beauty',
#   0.91,
#   'art',
#   0.64,
#   'engineering',
#   0.58),
#  (266863,
#   2701540,
#   1012681,
#   "Aren't you have a job?",
#   '你不在上班吧。',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'business',
#   0.65,
#   '',
#   0.0,
#   '',
#   0.0),
#  (283451,
#   2652552,
#   1029269,
#   'Are you able to guess my age?',
#   '你觉得我几岁?',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'conversation',
#   0.19,
#   '',
#   0.0,
#   '',
#   0.0),
#  (321858,
#   8824693,
#   1067676,
#   'I have an important promise tomorrow morning.',
#   '今天早上有了重要的约定。',
#   '2019_NIA_영한_대화',
#   '2019_NIA_영한_대화',
#   'business',
#   0.91,
#   'financial',
#   0.77,
#   'customer service',
#   0.53),
#  (892110,
#   5550112,
#   2386465,
#   'Soju is famous among them.',
#   '其中最有名的事烧酒。',
#   '2019_BYTEDANCE_중일',
#   '2019_BYTEDANCE_중일',
#   'beauty',
#   0.79,
#   'society',
#   0.65,
#   'art',
#   0.5),
#  (371925,
#   2599186,
#   1117743,
#   'People who need to use the toilet often should sit along the aisle.',
#   '经常上洗手间的人坐在靠过道的位子吧。',
#   '2019_NIA_영한_대화',
#   '2019_NIA_영한_대화',
#   'economy',
#   0.79,
#   'transport',
#   0.76,
#   'business',
#   0.65),
#  (5773037,
#   34742818,
#   22230786,
#   'In addition, there are quite a lot of Chinese businesses branched out in Tanzania, so I could see a lot of Chinese businessmen.',
#   '顺便说一下,中国的企业进军坦桑尼亚的相当多,在那里看见了很多的中国商人。',
#   None,
#   None,
#   'business',
#   0.97,
#   'commerce',
#   0.87,
#   'economy',
#   0.62),
#  (647614,
#   1839555,
#   1669145,
#   "What made the Korean women's volleyball team lose against Japanese and Chinese team in the World Grand Prix?",
#   '韩国女子排球队在世界杯当中输给日本和中国的原因是什么?',
#   '2019_GOOGLE_중영인일베',
#   '2019_GOOGLE_중영인일베',
#   'sports',
#   0.99,
#   '',
#   0.0,
#   '',
#   0.0),
#  (5773777,
#   34742897,
#   22648021,
#   "Yamagata Ramen restaurant looks small but there's an air of energy and warmth.",
#   '山形拉面店,虽然店内氛围非常整洁,但是也充斥着热闹、温暖的气氛。',
#   None,
#   None,
#   'business',
#   0.96,
#   'beauty',
#   0.96,
#   'customer service',
#   0.88),
#  (679305,
#   1824460,
#   1732870,
#   "What's included in the foreigners package?",
#   '外国人旅游套餐有包括什么?',
#   '2019_BYTEDANCE_중일',
#   '2019_BYTEDANCE_중일',
#   'travel',
#   0.89,
#   'financial',
#   0.52,
#   '',
#   0.0),
#  (5701791,
#   34735990,
#   22421395,
#   'I believeit is suitable for secondary use because there are counter seats or meals to enjoy with q couple of drinks.',
#   '有柜台席,可以一边喝酒一边吃点小菜,所以特别适合第二摊来这里。',
#   None,
#   None,
#   'beauty',
#   0.96,
#   'legal',
#   0.89,
#   'economy',
#   0.62),
#  (426726,
#   1226415,
#   2921539,
#   'I had many tests.',
#   '我做了很多测验。',
#   '2018_NTT_중영일한',
#   '2018_NTT_중영일한',
#   'science',
#   0.73,
#   'education',
#   0.54,
#   'engineering',
#   0.53),
#  (147114,
#   4943532,
#   2923849,
#   'My childhood friends are very comfortable and nice.',
#   '儿时的朋友就是好。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'beauty',
#   0.63,
#   'conversation',
#   0.54,
#   '',
#   0.0),
#  (530048,
#   1433209,
#   2926012,
#   "They didn't know it was a mistake.",
#   '他们不知道那个是个失误。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'transport',
#   0.57,
#   'travel',
#   0.54,
#   'financial',
#   0.53),
#  (382426,
#   1137761,
#   2949887,
#   'Calm down and take a test at home.',
#   '平静下来在家休息吧。',
#   '2019_NIA_영한_대화',
#   '2019_NIA_영한_대화',
#   'education',
#   0.85,
#   'computer',
#   0.63,
#   'economy',
#   0.52),
#  (550329,
#   1473810,
#   2954616,
#   'When does he play a video game?',
#   '他什么时候玩电子游戏?',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'technology',
#   0.9,
#   'computer',
#   0.69,
#   '',
#   0.0),
#  (932634,
#   2547659,
#   2960188,
#   'I will appreciate If you send me extra box.',
#   '如果你能寄我多一个厢子我会很感激你。',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'transport',
#   0.94,
#   'customer service',
#   0.94,
#   'commerce',
#   0.85),
#  (512367,
#   4769816,
#   2980465,
#   'Sometimes, you become my older sister.',
#   '有时候,你会成为我的姐姐。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'beauty',
#   0.34,
#   '',
#   0.0,
#   '',
#   0.0),
#  (628533,
#   1630801,
#   1800491,
#   'What is Aritaum for?',
#   'ARITAUM是干什么的地方?',
#   '2017_ETRI_아중영일한',
#   '2017_ETRI_아중영일한',
#   'religion',
#   0.75,
#   '',
#   0.0,
#   '',
#   0.0),
#  (629593,
#   1632926,
#   1814047,
#   'I should spend a night to see the sunrise.',
#   '想看日出的话就只能住一晚了。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'travel',
#   0.95,
#   'beauty',
#   0.9,
#   '',
#   0.0),
#  (5719433,
#   34737712,
#   22649812,
#   'There is also fruit flesh in an egg-shaped shaved ice, and it is very soft and delicious.',
#   '蛋形刨冰含有果肉,非常可爱又美味。',
#   None,
#   None,
#   'beauty',
#   0.93,
#   '',
#   0.0,
#   '',
#   0.0),
#  (5961883,
#   34760859,
#   22706464,
#   'This ball is held at Viennese royal palaces and each ballrooms, and about 5,000 participants visit every year.',
#   '这个舞会将在维也纳的王宫和各个舞蹈会场中举行,每年有5000多人前来参加。',
#   None,
#   None,
#   'beauty',
#   0.66,
#   '',
#   0.0,
#   '',
#   0.0),
#  (3970933,
#   1196538,
#   3008859,
#   'I am so sorry for your loss.',
#   '我为你的损失感到很遗憾。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'financial',
#   0.22,
#   '',
#   0.0,
#   '',
#   0.0),
#  (1534614,
#   4864020,
#   3009184,
#   'I envy that you speak English very well.',
#   '我很羡慕你英语讲得那么好。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'beauty',
#   0.8,
#   'conversation',
#   0.73,
#   'customer service',
#   0.51),
#  (259863,
#   2649470,
#   3014471,
#   'Maybe a beggar is living in my stomach.',
#   '我肚子里可能住着乞丐。',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'financial',
#   0.12,
#   '',
#   0.0,
#   '',
#   0.0),
#  (272861,
#   2794296,
#   3096381,
#   'You are the person who makes me lonely.',
#   '你是让我孤独的人。',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'economy',
#   0.28,
#   '',
#   0.0,
#   '',
#   0.0),
#  (953194,
#   2658285,
#   3019393,
#   'Because of you, I have to practice speaking.',
#   '因为你我要练习口语。',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'conversation',
#   0.61,
#   '',
#   0.0,
#   '',
#   0.0),
#  (258682,
#   2706373,
#   3046644,
#   'We decided to do the rest of the science research at my house.',
#   '剩下的研究科学在我们家里做。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'science',
#   0.97,
#   '',
#   0.0,
#   '',
#   0.0),
#  (503867,
#   1380823,
#   3049196,
#   'Saving money is a good habit.',
#   '存钱是好习惯。',
#   '2014_NAVER_영인',
#   '2014_NAVER_영인',
#   'financial',
#   0.99,
#   'economy',
#   0.87,
#   '',
#   0.0),
#  (960959,
#   2716478,
#   3052428,
#   "It's usually 15won.",
#   '大概十五元钱。',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'financial',
#   0.93,
#   'economy',
#   0.7,
#   'business',
#   0.67),
#  (21263,
#   8555374,
#   767082,
#   'It helps me a lot in developing my English skills.',
#   '那个对我英语提高有帮助。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'education',
#   0.85,
#   'liberal arts',
#   0.53,
#   'society',
#   0.51),
#  (39503,
#   2487820,
#   785322,
#   'I have to export it tomorrow.',
#   '我明天需要把它出口。',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'business',
#   0.99,
#   'transport',
#   0.98,
#   'commerce',
#   0.98),
#  (973179,
#   2807313,
#   3103817,
#   "Because I didn't spend good days recently.",
#   '我也不是过好日子。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'travel',
#   0.7,
#   'financial',
#   0.64,
#   'economy',
#   0.61),
#  (1563867,
#   4962454,
#   3106628,
#   'I am chatting without a translator.',
#   '是不是不用翻译器直接聊天的呀。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   '',
#   0.0,
#   '',
#   0.0,
#   '',
#   0.0),
#  (387210,
#   1147332,
#   3112652,
#   'Delete one of two.',
#   '删除两个中的一个。',
#   '2018_NTT_중영일한',
#   '2018_NTT_중영일한',
#   'business',
#   0.64,
#   'financial',
#   0.57,
#   '',
#   0.0),
#  (6114207,
#   22810038,
#   24361494,
#   'By the way, I miss the place again, looking back the picture of a small studio that I have stayed while I am arranging photos.',
#   '整理照片的时候看到我曾经逗留过的小影楼的照片,又开始想念那里。',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'liberal arts',
#   0.24,
#   '',
#   0.0,
#   '',
#   0.0),
#  (2571240,
#   9121750,
#   8010707,
#   'Please contact me whenever you have questions.',
#   '如有疑问,请随时联系。',
#   '2017_ETRI_아중영일한',
#   '2017_ETRI_아중영일한',
#   'customer service',
#   0.97,
#   '',
#   0.0,
#   '',
#   0.0),
#  (2572847,
#   8471292,
#   8014270,
#   "I think it's good for enjoying speed.",
#   '可以适合享受快捷的速度挺不错啊。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'technology',
#   0.84,
#   'travel',
#   0.68,
#   'computer',
#   0.65),
#  (1513463,
#   4802792,
#   5592978,
#   'So, I am trying to check everything now.',
#   '所以他让我以后检查一切。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'business',
#   0.87,
#   'computer',
#   0.63,
#   'customer service',
#   0.56),
#  (2574722,
#   9107745,
#   8018164,
#   'Where and at what time do you eat?',
#   '几点在哪里吃饭?',
#   '2018_APPLE_영일한',
#   '2018_APPLE_영일한',
#   'society',
#   0.07,
#   '',
#   0.0,
#   '',
#   0.0),
#  (6243705,
#   23070613,
#   24372181,
#   'While Eun-bae did the laundry first, Jisoo drank beer and I drank a glass of orange juice.',
#   '恩北先洗衣服的同时,智秀喝了一杯啤酒、一杯橙汁。',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'economy',
#   0.66,
#   '',
#   0.0,
#   '',
#   0.0),
#  (541022,
#   1455170,
#   5612092,
#   "We don't believe other people.",
#   '我们不推别人。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'society',
#   0.88,
#   '',
#   0.0,
#   '',
#   0.0),
#  (414978,
#   5797005,
#   5624775,
#   'I called you yesterday!',
#   '我最天给你打过电话。',
#   '2016_SYSTRAN_영한',
#   '2016_SYSTRAN_영한',
#   'customer service',
#   0.98,
#   'conversation',
#   0.98,
#   'business',
#   0.85),
#  (6910027,
#   25232720,
#   25232719,
#   'On the abandoned tin mine site, it was established here, and its facilities were distributed according to the original geology and landform.',
#   '这是在一座废弃锡矿遗址的基础上建立的,一切的设施分布均按照原有的地质地貌。',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'science',
#   0.61,
#   '',
#   0.0,
#   '',
#   0.0),
#  (6956278,
#   25325248,
#   25325247,
#   'Only the statue in the center of the square reminds people of its past.',
#   '只有广场的中央的雕像时刻提醒着人们它的过去。',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'art',
#   0.36,
#   '',
#   0.0,
#   '',
#   0.0),
#  (6170611,
#   22923545,
#   24382489,
#   'I could see shops more than homes.',
#   '比起家庭住宅,店铺看起来更多。',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'shopping',
#   0.95,
#   'commerce',
#   0.91,
#   'business',
#   0.9),
#  (944095,
#   2592864,
#   5633443,
#   "I'm trying to live positively.",
#   '用积极的心态,努力生活。',
#   '2019_NIA_영한_대화',
#   '2019_NIA_영한_대화',
#   'liberal arts',
#   0.69,
#   'economy',
#   0.64,
#   '',
#   0.0),
#  (6075610,
#   22732418,
#   24391058,
#   "It's hard to do snorkeling sometimes because the waves are high in winter.",
#   '冬天浪比较高,浮潜有时也会很累。',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'beauty',
#   0.26,
#   '',
#   0.0,
#   '',
#   0.0),
#  (6242684,
#   23068559,
#   24392944,
#   'It is good because it is not cold and hot either.',
#   '不冷不热真好。',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'beauty',
#   0.95,
#   'legal',
#   0.8,
#   'economy',
#   0.7),
#  (6266713,
#   23116879,
#   24405030,
#   'I ended up worrying without realizing it.',
#   '脚自动地滚了起来。',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'financial',
#   0.34,
#   '',
#   0.0,
#   '',
#   0.0),
#  (6142966,
#   22867919,
#   24406647,
#   'Once in Okinawa, and once in Osaka.',
#   '冲绳一次,大阪一次。',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'travel',
#   0.98,
#   'transport',
#   0.73,
#   'beauty',
#   0.68),
#  (6574076,
#   35142778,
#   24407976,
#   'At the same time, you will realize that you are penniless.',
#   '同时会意识到手里没有一分钱。',
#   None,
#   None,
#   'financial',
#   0.99,
#   'economy',
#   0.52,
#   '',
#   0.0),
#  (905628,
#   2441447,
#   5702629,
#   'If I do another works in that time.',
#   '如果在那个时间做别的事情的话。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'business',
#   0.87,
#   'economy',
#   0.64,
#   'art',
#   0.52),
#  (6926183,
#   25265040,
#   25265039,
#   'We ride around the island, there are golden reed marshes on one side and blue Yangtze River water on the other side.',
#   '沿着环岛公路骑行,一侧是金黄荡漾的的芦苇荡,一侧是碧蓝如洗的长江水。',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'travel',
#   0.98,
#   'beauty',
#   0.97,
#   'transport',
#   0.95),
#  (6109748,
#   22801066,
#   24319337,
#   'Later, those bargaining geniuses did so many impossible things.',
#   '从那以后,谈判天才做成了许多不可能的事情。',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'business',
#   0.52,
#   '',
#   0.0,
#   '',
#   0.0),
#  (6179031,
#   22940487,
#   24323090,
#   "Moreover, including weekends, it's three days.",
#   '加上周末之后才三天呢。',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'travel',
#   0.8,
#   'economy',
#   0.6,
#   'beauty',
#   0.59),
#  (2582224,
#   9106568,
#   8033867,
#   'Are there places where they sell clams in America?',
#   '没有也有卖蛤蚌的地方吗?',
#   '2018_APPLE_영일한',
#   '2018_APPLE_영일한',
#   'commerce',
#   0.74,
#   'business',
#   0.52,
#   '',
#   0.0),
#  (6990931,
#   25394576,
#   25394575,
#   'Of course, the above calculation is based on the normal exchange rate, not the airport exchange rate.',
#   '当然,以上的计算都是以正常汇率来算的,不能以机场汇率来换。',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'computer',
#   0.69,
#   '',
#   0.0,
#   '',
#   0.0),
#  (6181844,
#   22946147,
#   24436717,
#   'There were separate rooms for restaurants, weapons, and studying on the farm.',
#   '农场里是餐厅和军火库,书房在别的地方。',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'beauty',
#   0.35,
#   '',
#   0.0,
#   '',
#   0.0),
#  (6111971,
#   22805533,
#   24437516,
#   'The things that I can focus on now.',
#   '立刻就能努力去做的事。',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'customer service',
#   0.46,
#   '',
#   0.0,
#   '',
#   0.0),
#  (6165799,
#   22913862,
#   24335234,
#   'I must try all those foodie restaurants.',
#   '好吃的餐厅一定要尝一下啊。',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'beauty',
#   0.56,
#   '',
#   0.0,
#   '',
#   0.0),
#  (6294619,
#   23173032,
#   24340479,
#   'I decided to cross the Strait of Dover on a boat.',
#   '我决定乘船度过多佛海峡。',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'transport',
#   0.99,
#   'travel',
#   0.99,
#   'commerce',
#   0.74),
#  (6268302,
#   23120078,
#   24343318,
#   'Aveiro is a small village.',
#   '阿威罗是座小村庄。',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'beauty',
#   0.71,
#   'economy',
#   0.69,
#   '',
#   0.0),
#  (6249130,
#   23081522,
#   24344215,
#   "To enjoy time in Cuba, it's good to stay in a hotel that costs 120~130 cuc.",
#   '如果想在古巴好好活跃下气氛,应该住在120~130库克以上的酒店。',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'travel',
#   0.98,
#   'financial',
#   0.97,
#   'economy',
#   0.73),
#  (6139192,
#   22860320,
#   24344893,
#   'What was some memorable taxi talk?',
#   '各位有什么印象深刻的打车闲谈呢?',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'transport',
#   0.99,
#   'travel',
#   0.8,
#   'conversation',
#   0.64),
#  (2627489,
#   8429482,
#   8185186,
#   'Naturally, this restricts how the information can be used.',
#   '当然,这限制了如何使用的信息。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'patent',
#   0.83,
#   'information technology',
#   0.81,
#   'law',
#   0.71),
#  (6117990,
#   22817657,
#   24449620,
#   'The green hills will continue behind the trees.',
#   '树后面有一片葱绿的山丘。',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'beauty',
#   0.93,
#   '',
#   0.0,
#   '',
#   0.0),
#  (2630949,
#   8697457,
#   8192106,
#   'In addition, it will stimulate cooperation between regions.',
#   '此外,还将促进地区间的合作。',
#   '2018_BAIDU_독러영중태',
#   '2018_BAIDU_독러영중태',
#   'travel',
#   0.59,
#   'legal',
#   0.55,
#   'transport',
#   0.51),
#  (58352,
#   8857100,
#   804171,
#   'I will never say that I want to break up.',
#   '我绝对不跟你说分手。',
#   '2019_NIA_영한_대화',
#   '2019_NIA_영한_대화',
#   'computer',
#   0.45,
#   '',
#   0.0,
#   '',
#   0.0),
#  (460334,
#   1293690,
#   818119,
#   'I wish I got a girlfriend like you.',
#   '我希望有你这样的女朋友。',
#   '2014_NAVER_영인',
#   '2014_NAVER_영인',
#   'beauty',
#   0.89,
#   'conversation',
#   0.63,
#   '',
#   0.0),
#  (117155,
#   2729676,
#   862974,
#   "How long do you want your girl's hair want to be?",
#   '你喜欢头发长的女生还是短的女生?',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'fashion',
#   0.84,
#   'beauty',
#   0.73,
#   'conversation',
#   0.58),
#  (187292,
#   4904379,
#   933111,
#   "I got the message you've sent just now.",
#   '我现在才看到你发的电邮。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'social media',
#   0.96,
#   'customer service',
#   0.92,
#   'computer',
#   0.88),
#  (209290,
#   2549603,
#   955109,
#   'It is obvious to recognize korean plastic surgery.',
#   '韩国人整容很明显。',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'beauty',
#   0.44,
#   '',
#   0.0,
#   '',
#   0.0),
#  (214863,
#   2514190,
#   960682,
#   'I play piano when alone.',
#   '在我一个人的时候弹钢琴。',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'liberal arts',
#   0.54,
#   '',
#   0.0,
#   '',
#   0.0),
#  (246158,
#   2697049,
#   991977,
#   "I couldn't help being surprised during the time I was reading the Gospels.",
#   '我在读福音书的过程中,不得不惊讶。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'religion',
#   0.94,
#   'beauty',
#   0.62,
#   'literature',
#   0.62),
#  (255807,
#   2468599,
#   1001626,
#   'Was my first performance that I saw.',
#   '是我第一次看的表演。',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'art',
#   0.92,
#   'beauty',
#   0.7,
#   'sports',
#   0.63),
#  (259924,
#   2437348,
#   1005743,
#   'Thank you for liking my picture.',
#   '感谢你喜欢我的照片。',
#   '2016_NAVER_영인',
#   '2016_NAVER_영인',
#   'social media',
#   0.98,
#   'beauty',
#   0.77,
#   'art',
#   0.75),
#  (273863,
#   2823682,
#   1019681,
#   'She told me that you can do it as you said.',
#   '她说可以按照你说的做。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'legal',
#   0.98,
#   'conversation',
#   0.94,
#   'customer service',
#   0.93),
#  (276953,
#   2826158,
#   1022771,
#   'Try moving it again and if you still have trouble please text me.',
#   '你再次换换有问题了给我发短信。',
#   '2019_NIA_영한_대화',
#   '2019_NIA_영한_대화',
#   'customer service',
#   0.96,
#   'transport',
#   0.83,
#   'travel',
#   0.77),
#  (316818,
#   4984990,
#   1062636,
#   'When is the completion of building construction?',
#   '什么时候建完那个建筑?',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'business',
#   0.37,
#   '',
#   0.0,
#   '',
#   0.0),
#  (332070,
#   8517853,
#   1077888,
#   'We learned Taekwondo together when we were young.',
#   '我们小的时候一起学习了跆拳道。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'sports',
#   0.99,
#   '',
#   0.0,
#   '',
#   0.0),
#  (6807205,
#   25027024,
#   25027023,
#   "Malaysia's multi-culture always makes me feel surrounded by Indians.",
#   '马来西亚的多元文化总是让我觉得被印度人包围了。',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'society',
#   0.74,
#   'beauty',
#   0.74,
#   'conversation',
#   0.51),
#  (6823393,
#   25059408,
#   25059407,
#   'Huashan Gusong has different shapes and various poses.',
#   '特别是华山古松,真是形态各异,千姿百态。',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'art',
#   0.92,
#   'beauty',
#   0.83,
#   '',
#   0.0),
#  (6876517,
#   25165680,
#   25165679,
#   'The Manta is a very gentle animal.',
#   '蝠鲼是一种非常温和的动物。',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'beauty',
#   0.96,
#   '',
#   0.0,
#   '',
#   0.0),
#  (6880532,
#   25173712,
#   25173711,
#   'Most of the people will choose to spend nights in Dachaidan.',
#   '大部分人会选择在长途奔袭到大柴旦镇过夜。',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'society',
#   0.79,
#   'travel',
#   0.69,
#   'beauty',
#   0.57),
#  (7165996,
#   25744848,
#   25744847,
#   'The charm of stone forest lies not only in the natural landscape, but also in the unique local customs of Sani in stone forest.',
#   '石林的魅力不仅仅在自然景观,还在于独具特色的石林撒尼土著风情。',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'beauty',
#   0.97,
#   '',
#   0.0,
#   '',
#   0.0),
#  (6856336,
#   25125312,
#   25125311,
#   "The outer room is the living room, and in the middle it's study. Both of them are very suitable for office or friends gathering.",
#   '最外间是客厅,中间书房,会客办公或是好友小聚都非常适合。',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'beauty',
#   0.9,
#   'legal',
#   0.73,
#   '',
#   0.0),
#  (2513166,
#   9079689,
#   7893018,
#   'I visit the domestic branch once a month.',
#   '一个月一次访问国内分公司。',
#   '2018_APPLE_영일한',
#   '2018_APPLE_영일한',
#   'business',
#   0.81,
#   'customer service',
#   0.79,
#   'beauty',
#   0.66),
#  (398412,
#   1169751,
#   5522791,
#   'He found her for the first time.',
#   '他第一个发现了她。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'beauty',
#   0.85,
#   'customer service',
#   0.63,
#   'travel',
#   0.58),
#  (403628,
#   1180186,
#   5525380,
#   'How about eating out?',
#   '我们出去吃怎么样?',
#   '2019_NIA_영한_대화',
#   '2019_NIA_영한_대화',
#   'legal',
#   0.17,
#   '',
#   0.0,
#   '',
#   0.0),
#  (536439,
#   4785445,
#   5547428,
#   'Today, I had something amazing.',
#   '今天发生了一件奇怪的事。',
#   '2018_NTT_중영일한',
#   '2018_NTT_중영일한',
#   'beauty',
#   0.92,
#   'art',
#   0.8,
#   'technology',
#   0.72),
#  (6912003,
#   25236672,
#   25236671,
#   'On the ground floor, there is a sculpture commemorating Princess Diana, silently praying for those who pursue true love.',
#   '地下一层有纪念戴妃的雕塑,默默为追寻真爱的人祈祷!',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'art',
#   0.99,
#   'beauty',
#   0.82,
#   '',
#   0.0),
#  (2535986,
#   8463139,
#   7939147,
# ...
#   0.57,
#   '',
#   0.0),
#  (3818122,
#   12953435,
#   35775039,
#   'The businessman stirred onecq_marks stumps.',
#   '这个商人提出了一个难题',
#   '2018_APPLE_아중영일한러',
#   '2018_APPLE_아중영일한러',
#   'business',
#   0.99,
#   'commerce',
#   0.97,
#   'financial',
#   0.94),
#  (69911,
#   2718749,
#   21097227,
#   'Whenever my work is finished, I get empowered.',
#   '每次我的作品一完成我就浑身有力量了。',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'economy',
#   0.59,
#   'business',
#   0.52,
#   '',
#   0.0),
#  (1525801,
#   4836830,
#   21114191,
#   'Yesterday I heard Mary sing in the main hall.',
#   '昨天我听到马丽在礼堂唱歌。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   '',
#   0.0,
#   '',
#   0.0,
#   '',
#   0.0),
#  (11095293,
#   3997420,
#   35894940,
#   'The man is picking up the check.',
#   '那个男人在捡支票。',
#   '2016_SYSTRAN_영독러',
#   '2016_SYSTRAN_영독러',
#   'financial',
#   0.99,
#   'business',
#   0.98,
#   'commerce',
#   0.89),
#  (891202,
#   2382498,
#   21038003,
#   'I will do everything she wants.',
#   '我打算做她请求的所有事。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'customer service',
#   0.88,
#   'business',
#   0.66,
#   'legal',
#   0.65),
#  (2579273,
#   9118850,
#   21141899,
#   'Hello! Singing beggar who came last year survived and come back again.',
#   '你好!去年来过的贾科索尔没死,又来了。',
#   '2018_APPLE_영일한',
#   '2018_APPLE_영일한',
#   'travel',
#   0.98,
#   'conversation',
#   0.77,
#   '',
#   0.0),
#  (352206,
#   2625045,
#   21065780,
#   'I hope you have good grade.',
#   '祝你取得好成绩。',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'education',
#   0.67,
#   'economy',
#   0.57,
#   '',
#   0.0),
#  (2902707,
#   12280543,
#   21085715,
#   'Remember the battle fought by our socialist rapporteur, Mr. Desama.',
#   '还记得我们的社会主义报告员Desama先生所作的斗争。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'politics',
#   0.91,
#   '',
#   0.0,
#   '',
#   0.0),
#  (2683759,
#   8426871,
#   21090467,
#   'We need the 12-day rule for occasional cross-border coach services.',
#   '我们有时需要十二天的跨境巴士服务。',
#   '2020_MICROSOFT_14개언어',
#   '2020_MICROSOFT_14개언어',
#   'transport',
#   0.99,
#   'travel',
#   0.99,
#   'business',
#   0.96),
#  (1543368,
#   4890667,
#   21102201,
#   "I'm going to eat a steak and go see the United States' most representative statue, the Statue of Liberty.",
#   '我打算吃完牛排去看美国最具代表性的自由女神像。',
#   '2018_NTT_중영일한',
#   '2018_NTT_중영일한',
#   '',
#   0.0,
#   '',
#   0.0,
#   '',
#   0.0),
#  (34796,
#   4946726,
#   21106461,
#   'It is by no means that I am insulting them.',
#   '我绝不是辱骂他们。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'legal',
#   0.78,
#   'conversation',
#   0.52,
#   '',
#   0.0),
#  (896886,
#   2406947,
#   21172130,
#   'Yes I will make a chance to go there.',
#   '是的。一定会创造机会让你们去。',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'travel',
#   0.98,
#   'beauty',
#   0.9,
#   'liberal arts',
#   0.69),
#  (253441,
#   2453494,
#   21119768,
#   'It has changed me that I hang around in summer.',
#   '为了能在夏天走来走去,我要改变我自己。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'beauty',
#   0.37,
#   '',
#   0.0,
#   '',
#   0.0),
#  (5461869,
#   8767667,
#   21120576,
#   'We also need a reform in order to live up to our international commitments.',
#   '我们也需要通过改革,来履行我们的国际承诺。',
#   'NAVER_오픈사전',
#   'NAVER_오픈사전',
#   'economy',
#   0.6,
#   'society',
#   0.56,
#   '',
#   0.0),
#  (1294236,
#   4021852,
#   35904853,
#   'A slingshot or maybe a spear might work.',
#   '一把弹弓或一把长矛可能有用。',
#   '2016_SYSTRAN_영독러',
#   '2016_SYSTRAN_영독러',
#   '',
#   0.0,
#   '',
#   0.0,
#   '',
#   0.0),
#  (637697,
#   1649241,
#   21153177,
#   'Are there any ugly behaviors that can be seen in self-service coin laundry?',
#   '自助投币洗衣房里有看到很奇怪的人吗?',
#   '2014_ETRI_중영일한',
#   '2014_ETRI_중영일한',
#   'financial',
#   0.73,
#   '',
#   0.0,
#   '',
#   0.0),
#  (8749982,
#   29723260,
#   35922317,
#   "The store is open until nine o'clock in the evening.",
#   '这家店会一直开到晚上九点。',
#   '2020_MEGADIC_영프',
#   '2020_MEGADIC_영프',
#   'business',
#   0.99,
#   'commerce',
#   0.97,
#   'legal',
#   0.9),
#  (8877491,
#   30021894,
#   35933293,
#   'And Coach Parker, he credited that championship to Donna Martin.',
#   '而且帕克教练,他把冠军归功于唐娜·马丁。',
#   '2020_MICROSOFT_14개언어',
#   '2020_MICROSOFT_14개언어',
#   'sports',
#   0.95,
#   'conversation',
#   0.86,
#   'beauty',
#   0.85),
#  (1063748,
#   3557806,
#   34718458,
#   'Can the EU agree a deal to help migrants?',
#   '欧盟会达成协议来帮助移民吗?',
#   '2016_NAVER_영인',
#   '2016_NAVER_영인',
#   'politics',
#   0.82,
#   '',
#   0.0,
#   '',
#   0.0),
#  (8891340,
#   30054488,
#   35934522,
#   "I'd asked her to design something that a priest might have worn in 23rd-century Cairo.",
#   '我已经让她设计一件在23世纪开罗牧师可能会穿的衣服。',
#   '2020_MEGADIC_영프',
#   '2020_MEGADIC_영프',
#   'religion',
#   0.99,
#   'art',
#   0.69,
#   'beauty',
#   0.53),
#  (8891952,
#   30055883,
#   35934582,
#   'We were sitting peacefully at dinner, when all of a sudden the lights went out.',
#   '我们正平静地坐着吃晚餐,突然间,灯光熄灭了。',
#   '2020_MEGADIC_영프',
#   '2020_MEGADIC_영프',
#   'technology',
#   0.34,
#   '',
#   0.0,
#   '',
#   0.0),
#  (1066746,
#   3563807,
#   34720983,
#   'David Cameron overheard calling Nigeria & Afghanistan "fantastically corrupt countries" in chat with the Queen.',
#   '戴维.卡梅伦在与英国女王聊天时,称尼日利亚和阿富汗是"极其腐败的国家"',
#   '2016_NAVER_영인',
#   '2016_NAVER_영인',
#   'conversation',
#   0.99,
#   'politics',
#   0.97,
#   '',
#   0.0),
#  (1068993,
#   3568316,
#   34722913,
#   'Drum roll: Here are the nominees for Best Supporting Actor Oscars.',
#   '击鼓声:这里是奥斯卡最佳配角演员提名。',
#   '2016_NAVER_영인',
#   '2016_NAVER_영인',
#   'beauty',
#   0.27,
#   '',
#   0.0,
#   '',
#   0.0),
#  (1113387,
#   3657318,
#   34731779,
#   'Today they would be worth over $35 billion.',
#   '今天它们的价值会超过350亿美元。',
#   '2016_NAVER_영인',
#   '2016_NAVER_영인',
#   'financial',
#   0.99,
#   'business',
#   0.86,
#   'economy',
#   0.78),
#  (6415146,
#   26480278,
#   34823434,
#   'I was looking for it on the second basement floor.',
#   '我一直在地下2层找汽车来着。',
#   '2020_MICROSOFT_14개언어',
#   '2020_MICROSOFT_14개언어',
#   'travel',
#   0.73,
#   'business',
#   0.68,
#   'technology',
#   0.66),
#  (6353539,
#   23294983,
#   35106020,
#   "With Christian, I crossed the bridge to Aire-sur-l'Adour.",
#   '所以我要把克里斯蒂安摆在我面前,然后越过通往阿杜尔河畔艾尔的桥。',
#   '2020_MICROSOFT_14개언어',
#   '2020_MICROSOFT_14개언어',
#   'travel',
#   0.99,
#   'transport',
#   0.95,
#   'religion',
#   0.94),
#  (6354287,
#   23296532,
#   35106079,
#   'Listening to the fantastic performance while eating the granita, it gave me a damp feeling.',
#   '一边吃着格兰尼塔一边听着梦幻般的演奏,让因天气而略显压抑的心情重新被点燃。',
#   '2020_MICROSOFT_14개언어',
#   '2020_MICROSOFT_14개언어',
#   'beauty',
#   0.98,
#   'art',
#   0.84,
#   'technology',
#   0.56),
#  (11099066,
#   4027385,
#   35907143,
#   'Airplanes kept on droning in the distance throughout the night.',
#   '远处的飞机整夜不停地嗡嗡作响。',
#   '2016_SYSTRAN_영독러',
#   '2016_SYSTRAN_영독러',
#   'travel',
#   0.93,
#   'transport',
#   0.8,
#   '',
#   0.0),
#  (3748605,
#   12771253,
#   35908989,
#   'An air hostess was arrested and charged with drug smuggling.',
#   '一名空姐被捕并被控走私毒品。',
#   '2018_APPLE_아중영일한러',
#   '2018_APPLE_아중영일한러',
#   'travel',
#   0.98,
#   'transport',
#   0.9,
#   'law',
#   0.59),
#  (8684603,
#   29571170,
#   35917063,
#   'They were certainly not rich people but they had a sustainable price, they had a long-term contract for their product.',
#   '他们当然不是富人,但是他们有一个可维持的价格,他们的产品有长期的合同。',
#   '2020_MEGADIC_영프',
#   '2020_MEGADIC_영프',
#   'business',
#   0.99,
#   'financial',
#   0.98,
#   'legal',
#   0.94),
#  (6282872,
#   23149374,
#   35099666,
#   'When the rain stopped pouring, we entered the market and Yabeem bought cactus fruits for us.',
#   '雨停的时候,我们进了市场,Jabim给我们买了仙人掌果。',
#   '2020_MICROSOFT_14개언어',
#   '2020_MICROSOFT_14개언어',
#   'customer service',
#   0.97,
#   'shopping',
#   0.93,
#   'commerce',
#   0.92),
#  (8890796,
#   30053184,
#   35934463,
#   'We are doing this in Ireland, and the Information Society Commission clearly recognises the value of public libraries.',
#   '我们正在爱尔兰这样做,而且信息社会委员会清楚地认识到公共图书馆的价值。',
#   '2020_MEGADIC_영프',
#   '2020_MEGADIC_영프',
#   'legal',
#   0.98,
#   'society',
#   0.88,
#   'beauty',
#   0.77),
#  (8897859,
#   30069788,
#   35935138,
#   'I try to understand the origin of life on Earth and the possibilities of finding life elsewhere in the universe.',
#   '我尝试去理解地球上生命的起源和在宇宙中其他地方发现其他生命的可能性。',
#   '2020_MEGADIC_영프',
#   '2020_MEGADIC_영프',
#   'science',
#   0.98,
#   '',
#   0.0,
#   '',
#   0.0),
#  (1076317,
#   3582981,
#   34728992,
#   'Hillary Clinton: "Obviously, force should always be a last resort"',
#   '希拉里·克林顿:"显然,武力永远是最后的手段"',
#   '2016_NAVER_영인',
#   '2016_NAVER_영인',
#   'conversation',
#   0.7,
#   'politics',
#   0.68,
#   '',
#   0.0),
#  (1130197,
#   3691814,
#   34733944,
#   'Why do you like Indonesian culture?',
#   '你为什么喜欢印尼文化?',
#   '2016_NAVER_영인',
#   '2016_NAVER_영인',
#   '',
#   0.0,
#   '',
#   0.0,
#   '',
#   0.0),
#  (1132775,
#   3697044,
#   34734216,
#   'Can you help me put this shirt on?',
#   '你能帮我穿一下这件衬衫吗?',
#   '2016_NAVER_영인',
#   '2016_NAVER_영인',
#   '',
#   0.0,
#   '',
#   0.0,
#   '',
#   0.0),
#  (6449156,
#   23493848,
#   34826521,
#   'As understood, the locals also eat like that.',
#   '原来当地人也那样吃。',
#   '2020_MICROSOFT_14개언어',
#   '2020_MICROSOFT_14개언어',
#   'legal',
#   0.94,
#   'economy',
#   0.68,
#   'beauty',
#   0.65),
#  (6520119,
#   23641556,
#   34828482,
#   'The atmosphere will become stranger and stranger.',
#   '气氛会越来越奇怪的。',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'society',
#   0.57,
#   '',
#   0.0,
#   '',
#   0.0),
#  (10919654,
#   33152648,
#   35097616,
#   "I tried to book a train ticket to Hue on Saturday but I failed to authorize card, so I'll buy it tomorrow at the station.",
#   '为了预购星期六去顺化的火车票,争执了一阵子,结果信用卡认证失败了,决定明天去火车站买。',
#   None,
#   None,
#   'travel',
#   0.99,
#   'transport',
#   0.99,
#   'financial',
#   0.96),
#  (6291557,
#   23166868,
#   35100509,
#   "On the other hand, tracing back the history isn't always a pleasant experience.",
#   '相反,追溯到战争历史的话,并不是只有美好的回忆。',
#   '2020_MICROSOFT_14개언어',
#   '2020_MICROSOFT_14개언어',
#   'society',
#   0.49,
#   '',
#   0.0,
#   '',
#   0.0),
#  (4621625,
#   19105871,
#   34831335,
#   'If an actual Paralympic athlete was the speaker, I think people would sign up right away.',
#   '实际上残奥会的选手作为讲师马上就要进来了。',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'sports',
#   0.94,
#   '',
#   0.0,
#   '',
#   0.0),
#  (4621746,
#   19106113,
#   34831877,
#   'As for the Japanese team, I feel confident because there are many cheering squads.',
#   '日本队的应援团很多,他们应该很安心。',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'sports',
#   0.98,
#   'beauty',
#   0.88,
#   'social media',
#   0.73),
#  (6383232,
#   23356684,
#   35108587,
#   "It's nice to leave a picture of your memories, but the person you are traveling with is not the photographer.",
#   '虽然为了回忆留下照片是很好的,但是旅伴并不是专门摄影师。',
#   '2020_MICROSOFT_14개언어',
#   '2020_MICROSOFT_14개언어',
#   'travel',
#   0.97,
#   'transport',
#   0.92,
#   '',
#   0.0),
#  (6383677,
#   23357605,
#   35108623,
#   "I would ride if I have to, but at that time I felt 'why would I do it for extra 8 months'?",
#   '虽然说坐就坐,但是那时候在心里会有还要做8个月的感觉?',
#   '2020_MICROSOFT_14개언어',
#   '2020_MICROSOFT_14개언어',
#   'transport',
#   0.98,
#   'travel',
#   0.9,
#   'economy',
#   0.83),
#  (7592754,
#   27016925,
#   34023183,
#   "Go down along the road on the left, then you'll see.",
#   '沿着左边的路走下去,然后你就会看到。',
#   '2019_NIA_영한_대화',
#   '2019_NIA_영한_대화',
#   'travel',
#   0.98,
#   'beauty',
#   0.95,
#   'transport',
#   0.64),
#  (6616230,
#   35164185,
#   35112974,
#   'I went to Lawson in the Kansai Airport and bought a lot. I bought rolls, mochi, and some drinks but forgot that they are not allowed on board.',
#   '在关西机场有罗森,我去了买了一大堆,我买了卷蛋糕和日式年糕、饮料,但就忘了不能搬进到飞机内的事实。',
#   None,
#   None,
#   'travel',
#   0.96,
#   'shopping',
#   0.84,
#   'transport',
#   0.83),
#  (7588203,
#   27006320,
#   34025186,
#   'Nowadays, how is the pastors authority, arent there any ways to solve the modern churchs division and denomination?',
#   '现在,牧师的权威如何,有没有办法解决现代教会的分裂和教派?',
#   '2019_NIA_영한_대화',
#   '2019_NIA_영한_대화',
#   'religion',
#   0.97,
#   '',
#   0.0,
#   '',
#   0.0),
#  (7582512,
#   26993269,
#   34028389,
#   'Abolish the PO I sent yesterday, and issue invoice for the newly sent PO.',
#   '取消我昨天发出的订单,并为新发出的订单开具发票。',
#   '2019_NIA_영한_대화',
#   '2019_NIA_영한_대화',
#   'financial',
#   0.98,
#   'business',
#   0.98,
#   'customer service',
#   0.96),
#  (7571214,
#   26968397,
#   34034839,
#   "It is strange since it hasn't been found during the internal test before delivering samples.",
#   '这很奇怪,因为在交付样品之前,内部测试期间没有发现这个问题。',
#   '2019_NIA_영한_대화',
#   '2019_NIA_영한_대화',
#   'science',
#   0.71,
#   'technology',
#   0.67,
#   'engineering',
#   0.63),
#  (7562881,
#   26950193,
#   34039387,
#   'Reshipping shall compose of F specified sizes, which was returned.',
#   '重新装运应由F指定尺寸组成,并已被退回。',
#   '2019_NIA_영한_대화',
#   '2019_NIA_영한_대화',
#   'business',
#   0.87,
#   'law',
#   0.85,
#   'technology',
#   0.82),
#  (7554154,
#   26930823,
#   34045236,
#   'Upon receipt of payment in accordance with deadline, settlement was postponed for 20 minutes because of errors.',
#   '按期限收到付款后,由于出现错误,结算推迟了20分钟。',
#   '2019_NIA_영한_대화',
#   '2019_NIA_영한_대화',
#   'financial',
#   0.97,
#   'business',
#   0.93,
#   'customer service',
#   0.91),
#  (1057340,
#   3544979,
#   34051235,
#   'Actors Johnny Depp and Amber Heard are to divorce after 15 months of marriage.',
#   '演员约翰尼·德普和艾梅伯·希尔德在15个月的婚姻之后离婚了。',
#   '2016_NAVER_영인',
#   '2016_NAVER_영인',
#   'law',
#   0.73,
#   '',
#   0.0,
#   '',
#   0.0),
#  (1080015,
#   3590442,
#   35175526,
#   'I should just man up and kiss him.',
#   '我应该像男子汉一样勇敢一点去亲他。',
#   '2016_NAVER_영인',
#   '2016_NAVER_영인',
#   'business',
#   0.35,
#   '',
#   0.0,
#   '',
#   0.0),
#  (1088564,
#   3607616,
#   35182169,
#   'Love Indonesian food? Here are 40 dishes every visitor to the country should try.',
#   '喜欢印度尼西亚的食物吗?这里有40种食物,每一位来到该国的游客都应该试试：。',
#   '2016_NAVER_영인',
#   '2016_NAVER_영인',
#   'marketing',
#   0.9,
#   'travel',
#   0.57,
#   '',
#   0.0),
#  (326921,
#   4987438,
#   29247133,
#   "Because it's logical and it's interesting to watch the procedure of catching the criminal.",
#   '因为按照逻辑地去调查罪犯的过程很有趣。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'beauty',
#   0.82,
#   'legal',
#   0.77,
#   '',
#   0.0),
#  (2747555,
#   8482603,
#   9279388,
#   'If I stop now, it will be delayed.',
#   '如果在这停止的话,会更迟到的。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'travel',
#   0.97,
#   'business',
#   0.95,
#   'transport',
#   0.92),
#  (6150312,
#   22882712,
#   29228677,
#   'Enjoying the outside view and listening to favorite songs with Polypen.',
#   '一边欣赏外面的风景,一边用玩具笔听自己喜欢的歌曲。',
#   '2019_APPLE_중영일한',
#   '2019_APPLE_중영일한',
#   'technology',
#   0.96,
#   'beauty',
#   0.95,
#   'computer',
#   0.53),
#  (401727,
#   1176383,
#   13873618,
#   'He wants to visit to the festival with you in Manila.',
#   '他在马尼拉想和你参加大型活动。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'travel',
#   0.98,
#   'beauty',
#   0.61,
#   'conversation',
#   0.57),
#  (4083357,
#   6019749,
#   13886083,
#   "I swear, man it's all over.",
#   '虽然我发过誓,但现在全结束了。',
#   '2016_SYSTRAN_영한',
#   '2016_SYSTRAN_영한',
#   'computer',
#   0.57,
#   'law',
#   0.52,
#   'transport',
#   0.5),
#  (4084076,
#   6016502,
#   13888737,
#   'We will follow the guidance of a local health authority.',
#   '我们要听从地区健康负责人的指示。',
#   '2016_SYSTRAN_영한',
#   '2016_SYSTRAN_영한',
#   'medicine',
#   0.55,
#   'legal',
#   0.5,
#   '',
#   0.0),
#  (4018390,
#   5751046,
#   28620357,
#   'Also they came out w/ 6 issues in 3 months.',
#   '此外,他们在3个月内发行了6本书。',
#   '2016_SYSTRAN_영한',
#   '2016_SYSTRAN_영한',
#   'business',
#   0.93,
#   'customer service',
#   0.84,
#   'literature',
#   0.72),
#  (2522052,
#   9085617,
#   28623149,
#   'Do you know any district near here?',
#   '这附近的公交车站在哪里?',
#   '2018_APPLE_영일한',
#   '2018_APPLE_영일한',
#   'conversation',
#   0.65,
#   '',
#   0.0,
#   '',
#   0.0),
#  (7608648,
#   27053432,
#   31659986,
#   "It doesn't mean that you have to purchase everything at once.",
#   '这并不意味着你必须一次购清所有东西。',
#   '2020_MICROSOFT_14개언어',
#   '2020_MICROSOFT_14개언어',
#   'commerce',
#   0.85,
#   'financial',
#   0.78,
#   'shopping',
#   0.69),
#  (7612287,
#   27061765,
#   31661935,
#   'This blocks integrated thinking and disturbs communication with other areas.',
#   '这阻碍了综合思维,妨碍了和其他区域的交流。',
#   '2020_MICROSOFT_14개언어',
#   '2020_MICROSOFT_14개언어',
#   'society',
#   0.47,
#   '',
#   0.0,
#   '',
#   0.0),
#  (7623027,
#   27085856,
#   31668247,
#   'I want to become a flight attendant and make many people smile.',
#   '我想要成为飞机乘务员然后让很多人微笑。',
#   '2020_MICROSOFT_14개언어',
#   '2020_MICROSOFT_14개언어',
#   'transport',
#   0.99,
#   'travel',
#   0.99,
#   'customer service',
#   0.82),
#  (556775,
#   1486718,
#   28650248,
#   'Yes. It is me who saved you.',
#   '对。是我救了你。',
#   '2019_현대자동차_영한',
#   '2019_현대자동차_영한',
#   'customer service',
#   0.96,
#   'beauty',
#   0.72,
#   'legal',
#   0.71),
#  (7626954,
#   27094883,
#   31670019,
#   "Hopefully, our flight won't be delayed so we can check in before 2 am.",
#   '希望我们的飞机不会延误,那我们就能在2点前入住。',
#   '2020_MICROSOFT_14개언어',
#   '2020_MICROSOFT_14개언어',
#   'travel',
#   0.99,
#   'transport',
#   0.89,
#   'business',
#   0.61),
#  (351124,
#   2793906,
#   28658741,
#   'Jeju do is called Hawaii in Korea.',
#   '济州岛被称为是韩国的夏威夷。',
#   '2015_MEGADIC_중영한',
#   '2015_MEGADIC_중영한',
#   'travel',
#   0.95,
#   'beauty',
#   0.87,
#   '',
#   0.0),
#  ...]
